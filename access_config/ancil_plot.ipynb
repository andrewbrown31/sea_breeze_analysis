# %%
import ants
import iris
import iris.plot as iplt
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.crs as ccrs

# %%
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/mule/stashmaster.py:284: UserWarning: Ancillary files do not define the UM version number in the Fixed Length Header. No STASHmaster file loaded: Fields will not have STASH entries attached.
#   warnings.warn(msg)

# %%
#cubes = ants.load("/scratch/gb02/ab4502/cylc-run/u-cp145/share/data/ancils/aus2200/d0198/qrparm.mask")
cubes = ants.load("/scratch/gb02/ab4502/cylc-run/u-dg767/share/data/ancils/Gippsland/d1000/qrparm.mask")

cubes
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/mule/stashmaster.py:284: UserWarning: Ancillary files do not define the UM version number in the Fixed Length Header. No STASHmaster file loaded: Fields will not have STASH entries attached.
#   warnings.warn(msg)
# [<iris 'Cube' of m01s00i034 / (unknown) (latitude: 350; longitude: 350)>,
# <iris 'Cube' of m01s00i005 / (unknown) (latitude: 350; longitude: 350)>,
# <iris 'Cube' of m01s00i006 / (unknown) (latitude: 350; longitude: 350)>,
# <iris 'Cube' of m01s00i035 / (unknown) (latitude: 350; longitude: 350)>,
# <iris 'Cube' of m01s00i036 / (unknown) (latitude: 350; longitude: 350)>,
# <iris 'Cube' of m01s00i037 / (unknown) (latitude: 350; longitude: 350)>,
# <iris 'Cube' of m01s00i017 / (unknown) (latitude: 350; longitude: 350)>,
# <iris 'Cube' of m01s00i018 / (unknown) (latitude: 350; longitude: 350)>,
# <iris 'Cube' of m01s00i007 / (unknown) (latitude: 350; longitude: 350)>,
# ...

# %%
# mask = iris.load_cube("/scratch/gb02/ab4502/cylc-run/u-cp145/share/data/ancils/aus2200/d0198/qrparm.mask",
#                      "land_binary_mask")
# land_frac = iris.load_cube("/scratch/gb02/ab4502/cylc-run/u-cp145/share/data/ancils/aus2200/d0198/qrparm.mask",
#                      "land_area_fraction")

# mask_bc = iris.load_cube("/scratch/gb02/ab4502/cylc-run/u-cp145/share/data/ancils/aus2200/era5/qrparm.mask",
#                      "land_binary_mask")

mask_gippsland = iris.load_cube("/scratch/gb02/ab4502/cylc-run/u-dg767/share/data/ancils/Gippsland/d1000/qrparm.mask",
                     "land_binary_mask")
mask_lismore_nf33 = iris.load_cube("/g/data/nf33/public/training-day-2024/access-ram3/ancils/Lismore/d1000/qrparm.mask",
                     "land_binary_mask")
mask_lismore = iris.load_cube("/scratch/gb02/ab4502/cylc-run/u-dg767/share/data/ancils/Lismore/d1000/qrparm.mask",
                     "land_binary_mask")

plt.figure(figsize=[14,5])
plt.subplot(1,3,1)
xr.DataArray.from_iris(mask_gippsland).plot()
#plt.gca().gridlines(draw_labels=["bottom","left"])
print("Lon bounds",print(xr.DataArray.from_iris(mask_gippsland).latitude.min().values, xr.DataArray.from_iris(mask_gippsland).latitude.max().values))

plt.subplot(1,3,2)
xr.DataArray.from_iris(mask_lismore_nf33).plot()
#plt.gca().gridlines(draw_labels=["bottom","left"])
print("Lon bounds",print(xr.DataArray.from_iris(mask_lismore_nf33).latitude.min().values, xr.DataArray.from_iris(mask_lismore_nf33).latitude.max().values))

plt.subplot(1,3,3)
xr.DataArray.from_iris(mask_lismore).plot()
#plt.gca().gridlines(draw_labels=["bottom","left"])
print("Lon bounds",print(xr.DataArray.from_iris(mask_lismore).latitude.min().values, xr.DataArray.from_iris(mask_lismore).latitude.max().values))
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/mule/stashmaster.py:284: UserWarning: Ancillary files do not define the UM version number in the Fixed Length Header. No STASHmaster file loaded: Fields will not have STASH entries attached.
#   warnings.warn(msg)
# -55.38180160522461 -20.481800079345703
# Lon bounds None
# -51.0 -6.099998474121094
# Lon bounds None
# -51.0 -6.099998474121094
# Lon bounds None

# %%
ants.load("/scratch/gb02/ab4502/cylc-run/u-dg768/share/cycle/20240128T0000Z/Gippsland/d1000/GAL9/ics/GAL9_astart")
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/mule/stashmaster.py:259: UserWarning:
# Unable to load STASHmaster from version string, path does not exist
# Path: $UMDIR/vn13.0/ctldata/STASHmaster/STASHmaster_A
# Please check that the value of mule.stashmaster.STASHMASTER_PATH_PATTERN is correct for your site/configuration
#   warnings.warn(msg)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/mule/validators.py:198: UserWarning:
# File: /scratch/gb02/ab4502/cylc-run/u-dg768/share/cycle/20240128T0000Z/Gippsland/d1000/GAL9/ics/GAL9_astart
# Incorrect dataset_type (found 1, should be one of (4,))
# Incorrect number of integer constants, (found 46, should be 15)
# Incorrect number of real constants, (found 38, should be 6)
#   warnings.warn(msg)
# ...

# %%
xr.DataArray.from_iris(
    iris.load_cube("/scratch/gb02/ab4502/cylc-run/u-dg768/share/cycle/20240128T0000Z/Gippsland/d1000/GAL9/ics/GAL9_astart",
                     "x_wind")
).isnull().sum().values
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/mule/stashmaster.py:259: UserWarning:
# Unable to load STASHmaster from version string, path does not exist
# Path: $UMDIR/vn13.0/ctldata/STASHmaster/STASHmaster_A
# Please check that the value of mule.stashmaster.STASHMASTER_PATH_PATTERN is correct for your site/configuration
#   warnings.warn(msg)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/mule/validators.py:198: UserWarning:
# File: /scratch/gb02/ab4502/cylc-run/u-dg768/share/cycle/20240128T0000Z/Gippsland/d1000/GAL9/ics/GAL9_astart
# Incorrect dataset_type (found 1, should be one of (4,))
# Incorrect number of integer constants, (found 46, should be 15)
# Incorrect number of real constants, (found 38, should be 6)
#   warnings.warn(msg)
# ...
