# %%
from sea_breeze import load_model_data, utils
import xarray as xr
from dask.distributed import Client
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import logging
import datetime as dt
import pandas as pd

logging.getLogger("flox").setLevel(logging.WARNING)

# %%
def preprocess(ds):
    ds["time"] = pd.to_datetime(ds.time) + dt.timedelta(hours=11)
    #return ds["mask"].resample({"time":"1D"}).max()
    return ds["mask"].groupby(ds.time.dt.date).max()

def load(model,diagnostic,chunks={"time":10}):

    ds = xr.open_mfdataset("/g/data/ng72/ab4502/sea_breeze_detection/"+\
                      model+\
                      "/filters/filtered_mask_no_hourly_change_"+\
                      diagnostic+\
                      "_*.zarr/",
                 chunks=chunks, engine="zarr",preprocess=preprocess)
    
    return ds

def load_hourly(model,lat_slice,lon_slice,diagnostic,chunks={"time":10}):

    ds = xr.open_mfdataset("/g/data/ng72/ab4502/sea_breeze_detection/"+\
                      model+\
                      "/filters/filtered_mask_no_hourly_change_"+\
                      diagnostic+\
                      "_*.zarr/",
                 chunks=chunks, engine="zarr").sel(lat=lat_slice,lon=lon_slice)
    ds["time"] = pd.to_datetime(ds.time) + dt.timedelta(hours=11)
    
    return ds

def count_num_of_objs(da):
    x = np.unique(da)
    x = x[x!=0]
    x = x[~np.isnan(x)]
    return len(x)

def mask(ds,angle_ds,mask=True,mask_thresh=0.5):
    return xr.where(angle_ds.variance_interp<mask_thresh, ds, np.nan)

# %%
Client()
# Out:
# <Client: 'tcp://127.0.0.1:38783' processes=7 threads=14, memory=63.00 GiB>
# 2025-06-05 18:00:28,019 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-mask-4351b533e0194e97c1503915e266fdeb' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: DataNode(original-open_dataset-mask-4351b533e0194e97c1503915e266fdeb, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6d788d840>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# new run_spec: DataNode(original-open_dataset-mask-4351b533e0194e97c1503915e266fdeb, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6d7568940>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# old token: ('DataNode', '93db23f61b9bb64cff8955a0522a71a0')
# new token: ('DataNode', '753ccaf09fc6890ab060558e72a45e63')
# old dependencies: set()
# new dependencies: set()
#
# 2025-06-05 18:00:34,217 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36669 (pid=1404225) exceeded 95% memory budget. Restarting...
# 2025-06-05 18:00:34,311 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36669' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('sum-8167b70659ce4cad0f16d91e3bd37294', 33, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 38), ('sum-8167b70659ce4cad0f16d91e3bd37294', 46, 0, 0), 'original-open_dataset-mask-e8f01d127ce51d261c721a8795ec709f', ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 37, 0, 0), 'original-open_dataset-mask-adbc049751a13a769e3eb21081660960', ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 37), 'original-open_dataset-mask-b0905cb5a9cc3639ef83c65c982b1b44', ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 38, 0, 0), ('sum-8167b70659ce4cad0f16d91e3bd37294', 38, 0, 0), 'original-open_dataset-mask-dc0eb0bcbeb8a20d13337ba1fc0e0bea'} (stimulus_id='handle-worker-cleanup-1749110434.3106892')
# 2025-06-05 18:00:34,340 - distributed.nanny - WARNING - Restarting worker
# 2025-06-05 18:00:34,608 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39103 (pid=1404213) exceeded 95% memory budget. Restarting...
# 2025-06-05 18:00:34,660 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40799 (pid=1404217) exceeded 95% memory budget. Restarting...
# 2025-06-05 18:00:34,686 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39103' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 35), ('open_dataset-mask-concatenate-4c7e4954d8750a82eb171a0c3be979fa', 42, 0, 0), 'original-open_dataset-mask-f18aa4b30062dec75661a811dd889e8a', ('sum-8167b70659ce4cad0f16d91e3bd37294', 36, 0, 0), ('open_dataset-mask-concatenate-4c7e4954d8750a82eb171a0c3be979fa', 52, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 50), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 50, 0, 0), ('open_dataset-mask-concatenate-4c7e4954d8750a82eb171a0c3be979fa', 34, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 35, 0, 0), ('sum-8167b70659ce4cad0f16d91e3bd37294', 35, 0, 0), 'original-open_dataset-mask-6321ca87d019d834fa757aa78b133304'} (stimulus_id='handle-worker-cleanup-1749110434.6857994')
# 2025-06-05 18:00:34,704 - distributed.nanny - WARNING - Restarting worker
# 2025-06-05 18:00:34,732 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40799' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('groupby-cohort-eea96cc665f5a4a30a6b9e7968a67140', 0, 0, 1), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 48), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 47, 0, 0), ('groupby_max-chunk-95170529115dcaddfec92ec17386774d', 0, 0, 49), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 48, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 47), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 49, 0, 0), ('sum-8167b70659ce4cad0f16d91e3bd37294', 47, 0, 0), 'original-open_dataset-mask-5ab5c541e64842211708a38364326a1e', ('open_dataset-mask-concatenate-4c7e4954d8750a82eb171a0c3be979fa', 12, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 10, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 42)} (stimulus_id='handle-worker-cleanup-1749110434.7320852')
# 2025-06-05 18:00:34,738 - distributed.nanny - WARNING - Restarting worker
# 2025-06-05 18:00:44,462 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41703 (pid=1404232) exceeded 95% memory budget. Restarting...
# 2025-06-05 18:00:44,525 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41703' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 13), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 54, 0, 0), ('open_dataset-mask-concatenate-4c7e4954d8750a82eb171a0c3be979fa', 23, 0, 0), ('sum-8167b70659ce4cad0f16d91e3bd37294', 54, 0, 0), ('groupby-cohort-8aab85127138ba12c54667aec0042d32', 0, 0, 1), ('sum-8167b70659ce4cad0f16d91e3bd37294', 0, 0, 0), ('sum-8167b70659ce4cad0f16d91e3bd37294', 40, 0, 0), ('open_dataset-mask-concatenate-4c7e4954d8750a82eb171a0c3be979fa', 21, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 14), ('groupby-cohort-230facfa659ee6031291a341fbf830c9', 0, 0, 0), ('groupby-cohort-6ebb8fa44190e0b80752c39b115ca11d', 0, 0, 1), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 13, 0, 0), ('sum-partial-cb5d30d04d41e9b7c0fca3632e8857d2', 3, 0, 0), ('groupby-cohort-87866e9fa58110ef5b34e0175acd9179', 0, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 0, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 14, 0, 0)} (stimulus_id='handle-worker-cleanup-1749110444.5248013')
# 2025-06-05 18:00:44,533 - distributed.nanny - WARNING - Restarting worker
# 2025-06-05 18:00:45,159 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43867 (pid=1404209) exceeded 95% memory budget. Restarting...
# 2025-06-05 18:00:45,220 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43867' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 20, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa',
array-bf0971dc09cd4d5902aeb1e5974ee9e0', 25), ('concatenate-groupby_max-simple-reduce-aggregate-sum-6a814d63da18077e53dda3046b5dac5d', 6, 0, 0), ('sum-8167b70659ce4cad0f16d91e3bd37294', 50, 0, 0), ('sum-partial-732f5b51c8cabb3c84399e2f8ba1ddc3', 2, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 1, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 1), ('sum-8167b70659ce4cad0f16d91e3bd37294', 7, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 10, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 10), ('sum-8167b70659ce4cad0f16d91e3bd37294', 17, 0, 0), ('sum-8167b70659ce4cad0f16d91e3bd37294', 1, 0, 0)} (stimulus_id='handle-worker-cleanup-1749110455.992911')
# 2025-06-05 18:00:56,002 - distributed.nanny - WARNING - Restarting worker
# 2025-06-05 18:00:56,715 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43231 (pid=1404380) exceeded 95% memory budget. Restarting...
# 2025-06-05 18:00:56,795 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43231' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('groupby-cohort-91a138781089e5d10d7576df926e327e', 0, 0, 0), 'original-open_dataset-mask-4351b533e0194e97c1503915e266fdeb', ('groupby-cohort-87866e9fa58110ef5b34e0175acd9179', 0, 0, 1), ('sum-8167b70659ce4cad0f16d91e3bd37294', 29, 0, 0), ('sum-8167b70659ce4cad0f16d91e3bd37294', 16, 0, 0), ('groupby-cohort-4ae515e24d85f116feae293da0b86a4c', 0, 0, 1), ('sum-6a814d63da18077e53dda3046b5dac5d', 25, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 54), ('sum-8167b70659ce4cad0f16d91e3bd37294', 3, 0, 0), ('sum-8167b70659ce4cad0f16d91e3bd37294', 28, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 13, 0, 0), ('groupby-cohort-163266d19d2f7ba820cf059b65a37a0d', 0, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 28, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 0), ('sum-8167b70659ce4cad0f16d91e3bd37294', 49, 0, 0), ('groupby-cohort-0912b13e06784713c840819a295d073a', 0, 0, 1), ('sum-8167b70659ce4cad0f16d91e3bd37294', 15, 0, 0), ('groupby-cohort-9559e428a40236fab3608bf511ef6413', 0, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 13), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 28), ('sum-8167b70659ce4cad0f16d91e3bd37294', 13, 0, 0), ('sum-partial-cb5d30d04d41e9b7c0fca3632e8857d2', 6, 0, 0), ('groupby-cohort-201c30dc2e8279d3ea4e1771a340ca36', 0, 0, 1)} (stimulus_id='handle-worker-cleanup-1749110456.795573')
# 2025-06-05 18:00:56,802 - distributed.nanny - WARNING - Restarting worker
# 2025-06-05 18:01:01,059 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46413 (pid=1404389) exceeded 95% memory budget. Restarting...
# 2025-06-05 18:01:01,102 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46413' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('sum-8167b70659ce4cad0f16d91e3bd37294', 2, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 38), ('groupby-cohort-a9d43427ff3d92d371378c542334ebcf', 0, 0, 0), ('sum-partial-cb5d30d04d41e9b7c0fca3632e8857d2', 2, 0, 0), ('groupby-cohort-255ce77fba9cf086a57b893aca4ae094', 0, 0, 1), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 37), ('sum-6a814d63da18077e53dda3046b5dac5d', 11, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 38, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 50, 0, 0), ('sum-6a814d63da18077e53dda3046b5dac5d', 15, 0, 0), ('groupby_max-chunk-95170529115dcaddfec92ec17386774d', 0, 0, 43), ('groupby-cohort-a9d43427ff3d92d371378c542334ebcf', 0, 0, 1), ('sum-8167b70659ce4cad0f16d91e3bd37294', 12, 0, 0), ('groupby_max-chunk-95170529115dcaddfec92ec17386774d', 0, 0, 2), ('concatenate-groupby_max-simple-reduce-aggregate-sum-6a814d63da18077e53dda3046b5dac5d', 10, 0, 0), ('groupby-cohort-e7854da2c469a9b1514077524a0bd06d', 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1749110461.1021488')
# 2025-06-05 18:01:01,110 - distributed.nanny - WARNING - Restarting worker
# 2025-06-05 18:01:02,959 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46501 (pid=1404435) exceeded 95% memory budget. Restarting...
# 2025-06-05 18:01:03,020 - distributed.scheduler - ERROR - Task ('groupby_max-chunk-groupby-cohort-e6c531fbe0dd009e89c9dc5b24370a9c', 0, 0, 0) marked as failed because 4 workers died while trying to run it
# 2025-06-05 18:01:03,023 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46501' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('sum-partial-cb5d30d04d41e9b7c0fca3632e8857d2', 10, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 37, 0, 0), ('sum-8167b70659ce4cad0f16d91e3bd37294', 5, 0, 0), ('sum-partial-b84b7dacf57f00510388065daf1003fa', 11, 0, 0), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 37), ('sum-8167b70659ce4cad0f16d91e3bd37294', 6, 0, 0), ('sum-partial-cb5d30d04d41e9b7c0fca3632e8857d2', 9, 0, 0), ('open_dataset-mask-concatenate-4c7e4954d8750a82eb171a0c3be979fa', 50, 0, 0), ('concatenate-4c7e4954d8750a82eb171a0c3be979fa', 10, 0, 0), ('groupby-cohort-deaf0753e76e14912f7992b398f0cab0', 0, 0, 1), ('array-bf0971dc09cd4d5902aeb1e5974ee9e0', 10), ('sum-8167b70659ce4cad0f16d91e3bd37294', 48, 0, 0)} (stimulus_id='handle-worker-cleanup-1749110463.020255')
# 2025-06-05 18:01:03,044 - distributed.nanny - WARNING - Restarting worker
# 2025-06-05 18:02:59,297 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-mask-51666f40212cf5d8058e13d7443ddbbe' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: DataNode(original-open_dataset-mask-51666f40212cf5d8058e13d7443ddbbe, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6d787abc0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# new run_spec: DataNode(original-open_dataset-mask-51666f40212cf5d8058e13d7443ddbbe, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6d4ad7800>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# old token: ('DataNode', '2acc703889f45c983f4eb50748e26837')
# new token: ('DataNode', 'e7cd1dc4f7763d0359ef675f4900cb20')
# old dependencies: set()
# new dependencies: set()
#
# 2025-06-05 18:03:00,710 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-mask-5ab5c541e64842211708a38364326a1e' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: DataNode(original-open_dataset-mask-5ab5c541e64842211708a38364326a1e, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6d78773c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# new run_spec: DataNode(original-open_dataset-mask-5ab5c541e64842211708a38364326a1e, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6d4716f40>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# old token: ('DataNode', '9f7d42fcff446caa272509dee0980e0d')
# new token: ('DataNode', '8ac876251e34938963e7431d3dd946ec')
# old dependencies: set()
# new dependencies: set()
#
# 2025-06-05 18:04:29,922 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-mask-9e4059b0fb3ac51f58c626d5694be203' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: DataNode(original-open_dataset-mask-9e4059b0fb3ac51f58c626d5694be203, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b7014c17c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# new run_spec: DataNode(original-open_dataset-mask-9e4059b0fb3ac51f58c626d5694be203, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6d777edc0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# old token: ('DataNode', 'a3f2c2fbe50b285092769f213703be5b')
# new token: ('DataNode', '973efa55edda8b069a5861813aaac355')
# old dependencies: set()
# new dependencies: set()
#
# 2025-06-05 18:10:31,095 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-mask-a85a960aa37dac0e208773b97941b48b' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: DataNode(original-open_dataset-mask-a85a960aa37dac0e208773b97941b48b, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6d78c5d80>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# new run_spec: DataNode(original-open_dataset-mask-a85a960aa37dac0e208773b97941b48b, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6bebc7740>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# old token: ('DataNode', 'b9e61a5e4a4946c08c0bc62244172b5c')
# new token: ('DataNode', 'e0f7300819e52dd3d3f4867f3e9eefbc')
# old dependencies: set()
# new dependencies: set()
#
# 2025-06-05 18:10:56,470 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-66283c4af4ddcbd00d88262d15e684f2', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-66283c4af4ddcbd00d88262d15e684f2', 0, 0, 1) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-66283c4af4ddcbd00d88262d15e684f2', 0, 0, 1)->('groupby_max-chunk-groupby-cohort-66283c4af4ddcbd00d88262d15e684f2', 0, 0, 1))
# old token: 'a7ebd9cb91d4fded741e3ea571c592df'
# new token: ('1805cedd58d79bec', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 4)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-66283c4af4ddcbd00d88262d15e684f2', 0, 0, 1)}
#
# 2025-06-05 18:10:56,482 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-mask-9e4059b0fb3ac51f58c626d5694be203' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: DataNode(original-open_dataset-mask-9e4059b0fb3ac51f58c626d5694be203, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b7014c17c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# new run_spec: DataNode(original-open_dataset-mask-9e4059b0fb3ac51f58c626d5694be203, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6be9ec180>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# old token: ('DataNode', 'a3f2c2fbe50b285092769f213703be5b')
# new token: ('DataNode', '497f7a1746f5fa7b9a9790eae1d15663')
# old dependencies: set()
# new dependencies: set()
#
# 2025-06-05 18:10:56,548 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-52fe5cc692d031ad3c7ad24b591a2028', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-52fe5cc692d031ad3c7ad24b591a2028', 0, 0, 0) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-52fe5cc692d031ad3c7ad24b591a2028', 0, 0, 0)->('groupby_max-chunk-groupby-cohort-52fe5cc692d031ad3c7ad24b591a2028', 0, 0, 0))
# old token: '15507949462109992d593cc596bcb21d'
# new token: ('9e8d36c3c4e4c3ec', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 5)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-52fe5cc692d031ad3c7ad24b591a2028', 0, 0, 0)}
#
# 2025-06-05 18:10:56,559 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-d906ee453d7a0352f2fa658937753c21', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-d906ee453d7a0352f2fa658937753c21', 0, 0, 1) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-d906ee453d7a0352f2fa658937753c21', 0, 0, 1)->('groupby_max-chunk-groupby-cohort-d906ee453d7a0352f2fa658937753c21', 0, 0, 1))
# old token: 'a749743e6ff15f9060e9c88b0c0a50c6'
# new token: ('6501520faecf0d0c', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 46)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-d906ee453d7a0352f2fa658937753c21', 0, 0, 1)}
#
# 2025-06-05 18:10:56,569 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-59031b628edb66910ad3f1c2af2b9492', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-59031b628edb66910ad3f1c2af2b9492', 0, 0, 0) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-59031b628edb66910ad3f1c2af2b9492', 0, 0, 0)->('groupby_max-chunk-groupby-cohort-59031b628edb66910ad3f1c2af2b9492', 0, 0, 0))
# old token: '4e92e255b8b80fa90d4a6562cc0481c0'
# new token: ('fe61cd15eed114df', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 47)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-59031b628edb66910ad3f1c2af2b9492', 0, 0, 0)}
#
# 2025-06-05 18:10:56,570 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-b5d5a03cc3447e4cabc2431c8dd548bb', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-b5d5a03cc3447e4cabc2431c8dd548bb', 0, 0, 1) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-b5d5a03cc3447e4cabc2431c8dd548bb', 0, 0, 1)->('groupby_max-chunk-groupby-cohort-b5d5a03cc3447e4cabc2431c8dd548bb', 0, 0, 1))
# old token: '1aa3e8668a31ec3c0b233f5ed37499c5'
# new token: ('91af970f84ebcfa6', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 51)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-b5d5a03cc3447e4cabc2431c8dd548bb', 0, 0, 1)}
#
# 2025-06-05 18:10:56,579 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-fc578b0915beb93b0e689014543783af', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-fc578b0915beb93b0e689014543783af', 0, 0, 0) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-fc578b0915beb93b0e689014543783af', 0, 0, 0)->('groupby_max-chunk-groupby-cohort-fc578b0915beb93b0e689014543783af', 0, 0, 0))
# old token: 'd04369c825b5239e5bb7ae833f2ea13d'
# new token: ('eb0d485014796941', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 53)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-fc578b0915beb93b0e689014543783af', 0, 0, 0)}
#
# 2025-06-05 18:10:56,601 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-0fbe25e074f78ae400ee90c776fc7334', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-0fbe25e074f78ae400ee90c776fc7334', 0, 0, 1) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-0fbe25e074f78ae400ee90c776fc7334', 0, 0, 1)->('groupby_max-chunk-groupby-cohort-0fbe25e074f78ae400ee90c776fc7334', 0, 0, 1))
# old token: '52f00e2998c6eb950361b445ecc300e5'
# new token: ('060e1cee81d9e290', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 35)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-0fbe25e074f78ae400ee90c776fc7334', 0, 0, 1)}
#
# 2025-06-05 18:10:56,602 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-4a3c6cea892c3a0838bb526fe8557cca', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-4a3c6cea892c3a0838bb526fe8557cca', 0, 0, 1) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-4a3c6cea892c3a0838bb526fe8557cca', 0, 0, 1)->('groupby_max-chunk-groupby-cohort-4a3c6cea892c3a0838bb526fe8557cca', 0, 0, 1))
# old token: 'dccbe75d441700bd6646bdd03f901b1b'
# new token: ('a60b10b3242bbc1c', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 33)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-4a3c6cea892c3a0838bb526fe8557cca', 0, 0, 1)}
#
# 2025-06-05 18:10:59,480 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-mask-1761e9028cf1e06c96109b0adbe61576' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: DataNode(original-open_dataset-mask-1761e9028cf1e06c96109b0adbe61576, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6d78c9700>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# new run_spec: DataNode(original-open_dataset-mask-1761e9028cf1e06c96109b0adbe61576, type=<class 'xarray.core.indexing.ImplicitToExplicitIndexingAdapter'>, ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=BoolTypeArray(array=LazilyIndexedArray(array=<xarray.backends.zarr.ZarrArrayWrapper object at 0x14b6be57dcc0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None))))), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))))
# old token: ('DataNode', '808c9419727f7cb403a3a71c004eb0d9')
# new token: ('DataNode', 'ed3e8ae8430694437c2ce99a36f480c8')
# old dependencies: set()
# new dependencies: set()
#
# 2025-06-05 18:10:59,495 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-59031b628edb66910ad3f1c2af2b9492', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-59031b628edb66910ad3f1c2af2b9492', 0, 0, 1) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-59031b628edb66910ad3f1c2af2b9492', 0, 0, 1)->('groupby_max-chunk-groupby-cohort-59031b628edb66910ad3f1c2af2b9492', 0, 0, 1))
# old token: '7b585d6d5e3be842a5e73838a21929c8'
# new token: ('973947c137216e3e', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 48)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-59031b628edb66910ad3f1c2af2b9492', 0, 0, 1)}
#
# 2025-06-05 18:10:59,501 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-daad80a528330bea11fc4036531fcf8c', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-daad80a528330bea11fc4036531fcf8c', 0, 0, 0) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-daad80a528330bea11fc4036531fcf8c', 0, 0, 0)->('groupby_max-chunk-groupby-cohort-daad80a528330bea11fc4036531fcf8c', 0, 0, 0))
# old token: '711ac8132e5df464421d6e2990bf8058'
# new token: ('93104625d56da871', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 49)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-daad80a528330bea11fc4036531fcf8c', 0, 0, 0)}
#
# 2025-06-05 18:10:59,503 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-6db91b4ae13aea4bd6374172bc5924b7', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-6db91b4ae13aea4bd6374172bc5924b7', 0, 0, 0) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-6db91b4ae13aea4bd6374172bc5924b7', 0, 0, 0)->('groupby_max-chunk-groupby-cohort-6db91b4ae13aea4bd6374172bc5924b7', 0, 0, 0))
# old token: '47cca4df3dd39cd4c7978d15b5f5f8b2'
# new token: ('2e65b57c85d7fb74', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 46)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-6db91b4ae13aea4bd6374172bc5924b7', 0, 0, 0)}
#
# 2025-06-05 18:10:59,504 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-f4d89266d5d3d7df95e9c30742c12097', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-f4d89266d5d3d7df95e9c30742c12097', 0, 0, 1) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort
reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-ea425594973f1611c7fcd0d8ccf20181', 0, 0, 1)->('groupby_max-chunk-groupby-cohort-ea425594973f1611c7fcd0d8ccf20181', 0, 0, 1))
# old token: 'f4cd21db8e3f4fae480040ed1998fd93'
# new token: ('fc00b943a1888993', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 25)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-ea425594973f1611c7fcd0d8ccf20181', 0, 0, 1)}
#
# 2025-06-05 18:14:55,651 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-2617f49f890ac6bc37057dedd9eb8394', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-2617f49f890ac6bc37057dedd9eb8394', 0, 0, 0) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-2617f49f890ac6bc37057dedd9eb8394', 0, 0, 0)->('groupby_max-chunk-groupby-cohort-2617f49f890ac6bc37057dedd9eb8394', 0, 0, 0))
# old token: 'd74baf7f1da114c5ccee3b4c31bafd0e'
# new token: ('9ef83e6d61f8aa7b', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 21)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-2617f49f890ac6bc37057dedd9eb8394', 0, 0, 0)}
#
# 2025-06-05 18:14:55,652 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-5c117b566545a091c49557a2abe7a5f9', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-5c117b566545a091c49557a2abe7a5f9', 0, 0, 1) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-5c117b566545a091c49557a2abe7a5f9', 0, 0, 1)->('groupby_max-chunk-groupby-cohort-5c117b566545a091c49557a2abe7a5f9', 0, 0, 1))
# old token: 'b15566eef91fa1785bc873624219b290'
# new token: ('d2d345abc0a7a482', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 32)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-5c117b566545a091c49557a2abe7a5f9', 0, 0, 1)}
#
# 2025-06-05 18:14:55,669 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('groupby-cohort-daad80a528330bea11fc4036531fcf8c', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('groupby-cohort-daad80a528330bea11fc4036531fcf8c', 0, 0, 0) reindex_intermediates(...)>
# new run_spec: Alias(('groupby-cohort-daad80a528330bea11fc4036531fcf8c', 0, 0, 0)->('groupby_max-chunk-groupby-cohort-daad80a528330bea11fc4036531fcf8c', 0, 0, 0))
# old token: '711ac8132e5df464421d6e2990bf8058'
# new token: ('93104625d56da871', [])
# old dependencies: {('groupby_max-chunk-b0106d3c0353764d33f79dcc5494b59f', 0, 0, 49)}
# new dependencies: {('groupby_max-chunk-groupby-cohort-daad80a528330bea11fc4036531fcf8c', 0, 0, 0)}

# %%
#m="barra_c"

lat_slice = slice(-42,-35)
lon_slice = slice(144,151)

m="aus2200"
angle_ds = load_model_data.get_coastline_angle_kernel(
    compute=False,
    path_to_load="/g/data/ng72/ab4502/coastline_data/"+m+".nc",
    lat_slice=lat_slice,
    lon_slice=lon_slice
)
orog,lsm = load_model_data.load_barra_static("AUST-04",lon_slice,lat_slice)

# %%
#m = "barra_c_smooth_s2"
m = "aus2200_smooth_s4"
c = {"time":100}

#F = load(m,"F",chunks=c)
F_hourly = load_hourly(m,lat_slice,lon_slice,"F",chunks=c)
F = F_hourly.groupby(F_hourly.time.dt.date).max()

# %%
F_sum = (F.mask.sum("date") / F.mask.date.shape[0]).persist()

# %%
F_hourly_sum = F_hourly.mask.sum("time").persist()

# %%
def draw_boxes(lon_slice,lat_slice):

    plt.plot([lon_slice.start,lon_slice.stop,lon_slice.stop,lon_slice.start,lon_slice.start],
             [lat_slice.start,lat_slice.start,lat_slice.stop,lat_slice.stop,lat_slice.start],
             color="k",ls="--")    

zoom_box_lat = slice(-39,-37.9)
zoom_box_lon = slice(146.7,148)
p_lat = -38
p_lon = 147.5

#levels = np.linspace(0,0.4,6)
levels = [0,0.04,0.08,0.12,0.16,0.02,0.24,0.28,0.32]

ax=plt.axes(projection=ccrs.PlateCarree())
F_sum.sel(lat=lat_slice,lon=lon_slice).plot(cmap="Blues",levels=levels,cbar_kwargs={"label":"Fraction of sea breeze days"})
xr.plot.contourf(orog.sel(lat=lat_slice,lon=lon_slice),levels=[500,10000],extend="neither",colors=["grey"],alpha=0.6,hatches=["//"],add_colorbar=False)
xr.plot.contourf(angle_ds.variance_interp.sel(lat=lat_slice,lon=lon_slice),levels=[0.5,1],extend="neither",colors=["none"],alpha=0,hatches=["...."],add_colorbar=False)
ax.coastlines(lw=0.5)
draw_boxes(zoom_box_lon,zoom_box_lat)
#plt.plot(p_lon,p_lat,marker="x",color="k")
ax.gridlines(draw_labels=["left","bottom"],ls=":")

# %%
uas = []
vas = []
tas = []
hus = []
times = [("2013-01-01 00:00","2013-02-28 23:00"),
         ("2016-01-01 00:00","2016-02-29 23:00"),
         ("2018-01-01 00:00","2018-02-28 23:00")]
for t in times:

    vas.append(load_model_data.load_barra_variable(
                "vas",
                t[0],
                t[1],
                "AUST-04",
                "1hr",
                lat_slice,
                lon_slice,
                chunks={}))
    
    uas.append(load_model_data.load_barra_variable(
                "uas",
                t[0],
                t[1],
                "AUST-04",
                "1hr",
                lat_slice,
                lon_slice,
                chunks={}))

    tas.append(load_model_data.load_barra_variable(
                "tas",
                t[0],
                t[1],
                "AUST-04",
                "1hr",
                lat_slice,
                lon_slice,
                chunks={}))

    hus.append(load_model_data.load_barra_variable(
                "huss",
                t[0],
                t[1],
                "AUST-04",
                "1hr",
                lat_slice,
                lon_slice,
                chunks={}))    

uas = xr.concat(uas,"time")
vas = xr.concat(vas,"time")

# %%
tas = xr.concat(tas,"time")
hus = xr.concat(hus,"time")

# %%
ws = np.sqrt( uas**2 + vas**2 )

# %%
uas["time"] = pd.to_datetime(uas.time) + dt.timedelta(hours=11)
vas["time"] = pd.to_datetime(vas.time) + dt.timedelta(hours=11)
tas["time"] = pd.to_datetime(tas.time) + dt.timedelta(hours=11)
hus["time"] = pd.to_datetime(hus.time) + dt.timedelta(hours=11)
ws["time"] = pd.to_datetime(ws.time) + dt.timedelta(hours=11)

# %%
sbi_hourly = load_hourly(m,lat_slice,lon_slice,"sbi",chunks=c)
sbi = sbi_hourly.groupby(sbi_hourly.time.dt.date).max().persist()

# %%
# #Define sea breeze days as when there is a sea breeze object anywhere in the zoom box

#sb_ts = F.mask.sel(lat=zoom_box_lat,lon=zoom_box_lon).max(("lat","lon")).values
#sb_ts = sbi.mask.sel(lat=zoom_box_lat,lon=zoom_box_lon).max(("lat","lon")).values

sb_ts = (sbi.mask.sel(lat=zoom_box_lat,lon=zoom_box_lon).max(("lat","lon")).values) | (F.mask.sel(lat=zoom_box_lat,lon=zoom_box_lon).max(("lat","lon")).values)

#Number of days with a SB somewhere in the box
print(sb_ts.sum())
# Out:
# 138

# %%
print((~sb_ts).sum())
# Out:
# 43

# %%
#Frequency of SB days anywhere in box
print(sb_ts.sum() / F.mask.shape[0])
# Out:
# 0.7624309392265194

# %%
#Largest SB freq at any given point
F_sum.sel(lat=zoom_box_lat,lon=zoom_box_lon).max(("lat","lon")).values
# Out:
# array(0.24309392)

# %%
plt.figure(figsize=[12,6])

ax=plt.subplot(1,2,1,projection=ccrs.PlateCarree())
F.sel(date=sb_ts).mask.mean("date").plot(vmin=0,vmax=0.3)
ax.coastlines()

ax=plt.subplot(1,2,2,projection=ccrs.PlateCarree())
F.sel(date=~sb_ts).mask.mean("date").plot(vmin=0,vmax=0.3)
ax.coastlines()

# %%
plt.figure(figsize=[12,6])

ax=plt.subplot(1,2,1,projection=ccrs.PlateCarree())
sbi.sel(date=sb_ts).mask.mean("date").plot(vmin=0,vmax=0.3)
ax.coastlines()

ax=plt.subplot(1,2,2,projection=ccrs.PlateCarree())
sbi.sel(date=~sb_ts).mask.mean("date").plot(vmin=0,vmax=0.3)
ax.coastlines()

# %%
#Get the hourly times for the sea breeze dates

sb_hourly_times = (np.in1d(uas.time.dt.date,F.date[sb_ts]))
nonsb_hourly_times = np.in1d(uas.time.dt.date,F.date[~sb_ts])

# %%
#Slice the u and v wind to hourly times on sb days and non sb days. Group by hour and average

vas_sb_comp = vas.sel(time=sb_hourly_times).groupby("time.hour").mean().persist()
uas_sb_comp = uas.sel(time=sb_hourly_times).groupby("time.hour").mean().persist()
hus_sb_comp = hus.sel(time=sb_hourly_times).groupby("time.hour").mean().persist()
tas_sb_comp = tas.sel(time=sb_hourly_times).groupby("time.hour").mean().persist()

vas_nonsb_comp = vas.sel(time=nonsb_hourly_times).groupby("time.hour").mean().persist()
uas_nonsb_comp = uas.sel(time=nonsb_hourly_times).groupby("time.hour").mean().persist()
hus_nonsb_comp = hus.sel(time=nonsb_hourly_times).groupby("time.hour").mean().persist()
tas_nonsb_comp = tas.sel(time=nonsb_hourly_times).groupby("time.hour").mean().persist()

# %%
ws_sb_comp = ws.sel(time=sb_hourly_times).groupby("time.hour").mean().persist()

ws_nonsb_comp = ws.sel(time=nonsb_hourly_times).groupby("time.hour").mean().persist()

# %%
def plot_comp(ax,ds_u,ds_v,h,c,orog,ds_field=None,field_cmap="Blues",field_vmin=None,field_vmax=None,l=10,title=""):

    #ax=plt.subplot(1,2,1,projection=ccrs.PlateCarree())
    if ds_field is not None:
        fc=xr.plot.contourf(ds_field.sel(hour=h),cmap=field_cmap,vmin=field_vmin,vmax=field_vmax,levels=l,extend="max",add_colorbar=False,alpha=0.8)
        cs=xr.plot.contour(ds_field.sel(hour=h),vmin=field_vmin,vmax=field_vmax,levels=l,colors="k",linewidths=0.3)
        plt.clabel(cs)
        
    #xr.plot.contourf(orog,levels=[500,10000],extend="neither",colors=["grey"],alpha=0.6,add_colorbar=False)

    xr.Dataset({"u":ds_u,"v":ds_v}).sel(hour=h).coarsen({"lat":c,"lon":c},boundary="pad").mean().plot.quiver(
        x="lon",y="lat",u="u",v="v",scale=50,color="white",width=0.005,add_guide=False)
    
    ax.coastlines(lw=0.8)
    #draw_boxes(zoom_box_lon,zoom_box_lat)
    #plt.plot(p_lon,p_lat,marker="x",color="k")
    ax.gridlines(xlabel_style={"rotation":30},draw_labels=["left","bottom"],ls=":")    

    plt.title(title)

    if ds_field is not None:
        return fc


plt.figure(figsize=[16,10])

vmin=2
vmax=8
l=13
cmap="cividis"

ax=plt.subplot(2,3,1,projection=ccrs.PlateCarree())
fc=plot_comp(
    ax,
    uas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    5,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    ws_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Sea breeze days (05:00 am AEDT)")

ax=plt.subplot(2,3,4,projection=ccrs.PlateCarree())
fc=plot_comp(
    ax,
    uas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    5,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    ws_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Non sea breeze days (05:00 am AEDT)")

ax=plt.subplot(2,3,2,projection=ccrs.PlateCarree())
plot_comp(
    ax,
    uas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    11,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    ws_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Sea breeze days (11:00 am AEDT)")    

ax=plt.subplot(2,3,5,projection=ccrs.PlateCarree())
plot_comp(
    ax,
    uas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    11,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    ws_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Non sea breeze days (11:00 am AEDT)")    

ax=plt.subplot(2,3,3,projection=ccrs.PlateCarree())
plot_comp(
    ax,
    uas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    17,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    ws_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Sea breeze days (05:00 pm AEDT)")        

ax=plt.subplot(2,3,6,projection=ccrs.PlateCarree())
plot_comp(
    ax,
    uas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    17,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    ws_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Non sea breeze days (05:00 pm local time)")        


cb=plt.colorbar(fc,cax=plt.axes([0.2,0.05,0.6,0.01]),orientation="horizontal")
cb.set_label("Average wind speed at 10 m (m/s)")
#plt.subplots_adjust(hspace=0.3)

# %%
plt.figure(figsize=[12,12])

vmin=290
vmax=300
l=13
cmap="Reds"

ax=plt.subplot(3,2,1,projection=ccrs.PlateCarree())
fc=plot_comp(
    ax,
    uas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    11,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    tas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Sea breeze days (11:00 am local time)")

ax=plt.subplot(3,2,2,projection=ccrs.PlateCarree())
fc=plot_comp(
    ax,
    uas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    11,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    tas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Non sea breeze days (11:00 am local time)")

ax=plt.subplot(3,2,3,projection=ccrs.PlateCarree())
plot_comp(
    ax,
    uas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    14,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    tas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Sea breeze days (02:00 pm local time)")    

ax=plt.subplot(3,2,4,projection=ccrs.PlateCarree())
plot_comp(
    ax,
    uas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    14,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    tas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Non sea breeze days (02:00 pm local time)")    

ax=plt.subplot(3,2,5,projection=ccrs.PlateCarree())
plot_comp(
    ax,
    uas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    17,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    tas_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Sea breeze days (05:00 pm local time)")        

ax=plt.subplot(3,2,6,projection=ccrs.PlateCarree())
plot_comp(
    ax,
    uas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    vas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    17,
    3,
    orog.sel(lat=lat_slice,lon=lon_slice),
    tas_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
    l=l,
    field_vmin=vmin,
    field_vmax=vmax,
    field_cmap=cmap,
    title="Non sea breeze days (05:00 pm local time)")        


cb=plt.colorbar(fc,cax=plt.axes([0.2,0.05,0.6,0.01]),orientation="horizontal")
cb.set_label("Average wind speed at 10 m (m/s)")
plt.subplots_adjust(hspace=0.3)

# %%
plt.figure(figsize=[12,3])

xr.where(lsm.sel(lat=zoom_box_lat,lon=zoom_box_lon)==0,
ws_sb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
     np.nan).mean(("lat","lon")).plot(marker="o",label="Sea breeze days")

xr.where(lsm.sel(lat=zoom_box_lat,lon=zoom_box_lon)==0,
ws_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon),
     np.nan).mean(("lat","lon")).plot(marker="o",label="Non sea breeze days")

plt.legend()
plt.title("")
plt.ylabel("Average 10 m offshore wind speed")
plt.xlabel("Hour (AEDT)")
plt.gca().grid(ls=":")
# print(
#     xr.where(lsm.sel(lat=zoom_box_lat,lon=zoom_box_lon)==0,
#     ws_nonsb_comp.sel(lat=zoom_box_lat,lon=zoom_box_lon).sel(hour=[11,14,17]),
#          np.nan).mean(("lat","lon")).values
# )

# %%
plt.figure(figsize=[12,6])

h=0

ax=plt.subplot(1,2,1,projection=ccrs.PlateCarree())
xr.Dataset({"u":uas_sb_comp,"v":vas_sb_comp}).sel(hour=h).coarsen({"lat":6,"lon":6},boundary="pad").mean().plot.quiver(
    x="lon",y="lat",u="u",v="v",scale=100)

xr.plot.contourf(orog.sel(lat=lat_slice,lon=lon_slice),levels=[500,10000],extend="neither",colors=["grey"],alpha=0.6,add_colorbar=False)
ax.coastlines(lw=0.5)
draw_boxes(zoom_box_lon,zoom_box_lat)
plt.plot(p_lon,p_lat,marker="x",color="k")
ax.gridlines(draw_labels=["left","bottom"],ls=":")


plt.title("SB days")

ax=plt.subplot(1,2,2,projection=ccrs.PlateCarree())
xr.Dataset({"u":uas_nonsb_comp,"v":vas_nonsb_comp}).sel(hour=h).coarsen({"lat":6,"lon":6},boundary="pad").mean().plot.quiver(
    x="lon",y="lat",u="u",v="v",scale=100)
ax.coastlines()

xr.plot.contourf(orog.sel(lat=lat_slice,lon=lon_slice),levels=[500,10000],extend="neither",colors=["grey"],alpha=0.6,add_colorbar=False)
ax.coastlines(lw=0.5)
draw_boxes(zoom_box_lon,zoom_box_lat)
plt.plot(p_lon,p_lat,marker="x",color="k")
ax.gridlines(draw_labels=["left","bottom"],ls=":")

plt.title("Non-SB days")




plt.figure(figsize=[12,6])

h=3

ax=plt.subplot(1,2,1,projection=ccrs.PlateCarree())
xr.Dataset({"u":uas_sb_comp,"v":vas_sb_comp}).sel(hour=h).coarsen({"lat":6,"lon":6},boundary="pad").mean().plot.quiver(
    x="lon",y="lat",u="u",v="v",scale=100)

xr.plot.contourf(orog.sel(lat=lat_slice,lon=lon_slice),levels=[500,10000],extend="neither",colors=["grey"],alpha=0.6,add_colorbar=False)
ax.coastlines(lw=0.5)
draw_boxes(zoom_box_lon,zoom_box_lat)
plt.plot(p_lon,p_lat,marker="x",color="k")
ax.gridlines(draw_labels=["left","bottom"],ls=":")


plt.title("SB days")

ax=plt.subplot(1,2,2,projection=ccrs.PlateCarree())
xr.Dataset({"u":uas_nonsb_comp,"v":vas_nonsb_comp}).sel(hour=h).coarsen({"lat":6,"lon":6},boundary="pad").mean().plot.quiver(
    x="lon",y="lat",u="u",v="v",scale=100)
ax.coastlines()

xr.plot.contourf(orog.sel(lat=lat_slice,lon=lon_slice),levels=[500,10000],extend="neither",colors=["grey"],alpha=0.6,add_colorbar=False)
ax.coastlines(lw=0.5)
draw_boxes(zoom_box_lon,zoom_box_lat)
plt.plot(p_lon,p_lat,marker="x",color="k")
ax.gridlines(draw_labels=["left","bottom"],ls=":")

plt.title("Non-SB days")
# Out:
# Text(0.5, 1.0, 'Non-SB days')

# %%
F_sb_comp = F_hourly.sel(lat=lat_slice,lon=lon_slice).mask.sel(time=sb_comp_times).sum("time").persist()
F_nonsb_comp = F_hourly.sel(lat=lat_slice,lon=lon_slice).mask.sel(time=nonsb_comp_times).sum("time").persist()

# %%
plt.figure(figsize=[12,6])

ax=plt.subplot(1,2,1,projection=ccrs.PlateCarree())
F_sb_comp.plot(cmap="Blues")
ax.coastlines()

ax=plt.subplot(1,2,2,projection=ccrs.PlateCarree())
F_nonsb_comp.plot(cmap="Blues")
ax.coastlines()

# %%
uas
# Out:
# <xarray.DataArray 'uas' (time: 4272, lat: 175, lon: 175)> Size: 1GB
# dask.array<concatenate, shape=(4272, 175, 175), dtype=float64, chunksize=(12, 123, 108), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 34kB 2013-01-01 ... 2018-02-28T23:00:00
#     height   float64 8B 10.0
#   * lon      (lon) float64 1kB 144.0 144.1 144.1 144.1 ... 150.9 150.9 151.0
#   * lat      (lat) float64 1kB -41.97 -41.93 -41.89 ... -35.09 -35.05 -35.01
#     crs      int32 4B 0
# Attributes:
#     long_name:      Eastward Near-Surface Wind
#     standard_name:  eastward_wind
#     units:          m s-1
#     cell_methods:   time: point (interval: 1H) area: interpolation (method: b...
#     grid_mapping:   crs
#     smoothed:       False
