# %%
from sea_breeze import load_model_data, utils
import xarray as xr
from dask.distributed import Client
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import hvplot.xarray
import numpy as np
import logging

logging.getLogger("flox").setLevel(logging.WARNING)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='8242bbd7-94b7-4d3c-b257-3241926e9ee1'>
#   <div id="a5db485a-978a-4e7d-a17e-11eec71b6a3f" data-root-id="8242bbd7-94b7-4d3c-b257-3241926e9ee1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
def load(model,diagnostic,chunks={"time":10}):

    ds = xr.open_mfdataset("/g/data/ng72/ab4502/sea_breeze_detection/"+\
                      model+\
                      "/filters/filtered_mask_no_hourly_change_"+\
                      diagnostic+\
                      "_*.zarr/",
                 chunks=chunks, engine="zarr")   
    
    return ds

def count_num_of_objs(da):
    return len(np.unique(da))-1

def mask(ds,angle_ds,mask=True,mask_thresh=0.5):
    return xr.where(angle_ds.variance_interp<mask_thresh, ds, np.nan)

# %%
Client()
# Out:
# <Client: 'tcp://127.0.0.1:36031' processes=7 threads=14, memory=63.00 GiB>

# %%
angle_list = []
models = ["aus2200","barra_c","barra_r","era5"]
for m in models:
    angle_ds = load_model_data.get_coastline_angle_kernel(
        compute=False,
        path_to_load="/g/data/ng72/ab4502/coastline_data/"+m+".nc",
        lat_slice=slice(-45.7,-6.9),
        lon_slice=slice(108,158.5)
    )
    angle_list.append(angle_ds)

# %%
models = ["aus2200_smooth_s4","barra_c_smooth_s2","barra_r","era5"]
chunks = [{"time":50},{"time":100},{"time":-1},{"time":-1}]

Fc_list = []
for m,c in zip(models,chunks):
    print(m)
    temp = load(m,"Fc",chunks=c)
    Fc_list.append(
        temp
    )

F_list = []
for m,c in zip(models,chunks):
    print(m)
    temp = load(m,"F",chunks=c)
    F_list.append(
        temp
    )    

fuzzy_list = []
for m,c in zip(models,chunks):
    print(m)
    temp = load(m,"fuzzy",chunks=c)
    fuzzy_list.append(
        temp
    )


models = ["aus2200_smooth_s4","era5"]
chunks = [{"time":50},{"time":-1}]

sbi_list = []
for m,c in zip(models,chunks):
    print(m)
    temp = load(m,"sbi",chunks=c)
    sbi_list.append(
        temp
    )
# Out:
# aus2200_smooth_s4
# barra_c_smooth_s2
# barra_r
# era5
# aus2200_smooth_s4
# barra_c_smooth_s2
# barra_r
# era5
# aus2200_smooth_s4
# barra_c_smooth_s2
# barra_r
# era5
# aus2200_smooth_s4
# era5

# %%
perth_lat, perth_lon = utils.get_perth_bounds()
darwin_lat, darwin_lon = utils.get_darwin_bounds()
gipps_lat,gipps_lon = utils.get_gippsland_bounds()
large_perth_lat, large_perth_lon = utils.get_perth_large_bounds()

# %%
plt.figure(figsize=[18,12])

ax=plt.subplot(2,2,1,projection=ccrs.PlateCarree())
Fc_list[0].mask.sel(lat=large_perth_lat,lon=large_perth_lon).sum("time").plot(cmap="Blues",robust=True,vmin=0,vmax=200)
plt.plot([perth_lon.start,perth_lon.stop,perth_lon.stop,perth_lon.start,perth_lon.start],
         [perth_lat.start,perth_lat.start,perth_lat.stop,perth_lat.stop,perth_lat.start],
         color="k",ls="--")
ax.coastlines()

ax=plt.subplot(2,2,2,projection=ccrs.PlateCarree())
F_list[0].mask.sel(lat=large_perth_lat,lon=large_perth_lon).sum("time").plot(cmap="Blues",robust=True,vmin=0,vmax=200)
plt.plot([perth_lon.start,perth_lon.stop,perth_lon.stop,perth_lon.start,perth_lon.start],
         [perth_lat.start,perth_lat.start,perth_lat.stop,perth_lat.stop,perth_lat.start],
         color="k",ls="--")
ax.coastlines()

ax=plt.subplot(2,2,3,projection=ccrs.PlateCarree())
sbi_list[0].mask.sel(lat=large_perth_lat,lon=large_perth_lon).sum("time").plot(cmap="Blues",robust=True,vmin=0,vmax=200)
plt.plot([perth_lon.start,perth_lon.stop,perth_lon.stop,perth_lon.start,perth_lon.start],
         [perth_lat.start,perth_lat.start,perth_lat.stop,perth_lat.stop,perth_lat.start],
         color="k",ls="--")
ax.coastlines()

ax=plt.subplot(2,2,4,projection=ccrs.PlateCarree())
fuzzy_list[0].mask.sel(lat=large_perth_lat,lon=large_perth_lon).sum("time").plot(cmap="Blues",robust=True,vmin=0,vmax=200)
plt.plot([perth_lon.start,perth_lon.stop,perth_lon.stop,perth_lon.start,perth_lon.start],
         [perth_lat.start,perth_lat.start,perth_lat.stop,perth_lat.stop,perth_lat.start],
         color="k",ls="--")
ax.coastlines()

# %%
lat_slice=darwin_lat
lon_slice=darwin_lon

plt.figure(figsize=[18,12])

ax=plt.subplot(2,2,1,projection=ccrs.PlateCarree())
mask(
    F_list[0].mask.sel(lat=lat_slice,lon=lon_slice).sum("time"),
    angle_list[0].sel(lat=lat_slice,lon=lon_slice)).plot(cmap="Blues",levels=np.linspace(0,80,11))
ax.coastlines()
xr.plot.contourf(angle_list[0].sel(lat=lat_slice,lon=lon_slice).variance_interp,levels=[0.,0.5],hatches=["","////"],colors="none",add_colorbar=False)

ax=plt.subplot(2,2,2,projection=ccrs.PlateCarree())
mask(
    Fc_list[0].mask.sel(lat=lat_slice,lon=lon_slice).sum("time"),
    angle_list[0].sel(lat=lat_slice,lon=lon_slice)).plot(cmap="Blues",levels=np.linspace(0,80,11))
ax.coastlines()
xr.plot.contourf(angle_list[0].sel(lat=lat_slice,lon=lon_slice).variance_interp,levels=[0.,0.5],hatches=["","////"],colors="none",add_colorbar=False)

ax=plt.subplot(2,2,3,projection=ccrs.PlateCarree())
mask(
    sbi_list[0].mask.sel(lat=lat_slice,lon=lon_slice).sum("time"),
    angle_list[0].sel(lat=lat_slice,lon=lon_slice)).plot(cmap="Blues",levels=np.linspace(0,80,11))
ax.coastlines()
xr.plot.contourf(angle_list[0].sel(lat=lat_slice,lon=lon_slice).variance_interp,levels=[0.,0.5],hatches=["","////"],colors="none",add_colorbar=False)

ax=plt.subplot(2,2,4,projection=ccrs.PlateCarree())
mask(
    fuzzy_list[0].mask.sel(lat=lat_slice,lon=lon_slice).sum("time"),
    angle_list[0].sel(lat=lat_slice,lon=lon_slice)).plot(cmap="Blues",levels=np.linspace(0,80,11))
ax.coastlines()
xr.plot.contourf(angle_list[0].sel(lat=lat_slice,lon=lon_slice).variance_interp,levels=[0.,0.5],hatches=["","////"],colors="none",add_colorbar=False)

# %%
def count_num_of_objs(da):
    return len(np.unique(da))-1

xr.apply_ufunc(
    count_num_of_objs,
    Fc_list_ds[0].filtered_labels.sel(lat=perth_lat,lon=perth_lon),
    input_core_dims=[["lat","lon"]],
    dask="parallelized",
    vectorize=True).groupby("time.hour").sum().plot()

# %%
def draw_boxes(lon_slice,lat_slice):

    plt.plot([lon_slice.start,lon_slice.stop,lon_slice.stop,lon_slice.start,lon_slice.start],
             [lat_slice.start,lat_slice.start,lat_slice.stop,lat_slice.stop,lat_slice.start],
             color="k",ls="--")    

def get_gippsland_bounds():
    lat_slice = slice(-39.5, -36.5)
    lon_slice = slice(146, 149)
    return lat_slice, lon_slice

perth_lat, perth_lon = utils.get_perth_bounds()
darwin_lat, darwin_lon = utils.get_darwin_bounds()
gipps_lat,gipps_lon = get_gippsland_bounds()

plt.figure(figsize=[18,18])

ax=plt.subplot(3,2,1,projection=ccrs.PlateCarree())
F_list[0].mask.sum("time").plot(cmap="Blues",robust=True,vmin=0,vmax=200)
draw_boxes(perth_lon,perth_lat)
draw_boxes(darwin_lon,darwin_lat)
draw_boxes(gipps_lon,gipps_lat)
ax.coastlines()

# ax=plt.subplot(3,2,3,projection=ccrs.PlateCarree())
# sbi_list[0].sum("time").plot(cmap="Blues",robust=True,vmin=0,vmax=200)
# plt.plot([perth_lon.start,perth_lon.stop,perth_lon.stop,perth_lon.start,perth_lon.start],
#          [perth_lat.start,perth_lat.start,perth_lat.stop,perth_lat.stop,perth_lat.start],
#          color="k",ls="--")
# ax.coastlines()

# ax=plt.subplot(3,2,5,projection=ccrs.PlateCarree())
# fuzzy_list[0].sum("time").plot(cmap="Blues",robust=True,vmin=0,vmax=200)
# plt.plot([perth_lon.start,perth_lon.stop,perth_lon.stop,perth_lon.start,perth_lon.start],
#          [perth_lat.start,perth_lat.start,perth_lat.stop,perth_lat.stop,perth_lat.start],
#          color="k",ls="--")
# ax.coastlines()

ax=plt.subplot(3,2,2)
# Fc_list[0].mask.sel(lat=darwin_lat,lon=darwin_lon).mean(("lat","lon")).groupby("time.hour").mean().plot(label="AUS2200 Fc",marker="o")
# sbi_list[0].mask.sel(lat=darwin_lat,lon=darwin_lon).mean(("lat","lon")).groupby("time.hour").mean().plot(label="AUS2200 SBI",marker="o")
# fuzzy_list[0].mask.sel(lat=darwin_lat,lon=darwin_lon).mean(("lat","lon")).groupby("time.hour").mean().plot(label="AUS2200 fuzzy",marker="o")
#Fc_list[0].sel(lat=darwin_lat,lon=darwin_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="AUS2200 Fc",marker="o")
#sbi_list[0].sel(lat=darwin_lat,lon=darwin_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="AUS2200 SBI",marker="o")
#fuzzy_list[0].sel(lat=darwin_lat,lon=darwin_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="AUS2200 fuzzy",marker="o")
xr.apply_ufunc(
    count_num_of_objs,
    F_list[0].filtered_labels.sel(lat=darwin_lat,lon=darwin_lon),
    input_core_dims=[["lat","lon"]],
    dask="parallelized",
    vectorize=True).groupby("time.hour").sum().plot(label="AUS2200 Fc",marker="o")
xr.apply_ufunc(
    count_num_of_objs,
    sbi_list[0].filtered_labels.sel(lat=darwin_lat,lon=darwin_lon),
    input_core_dims=[["lat","lon"]],
    dask="parallelized",
    vectorize=True).groupby("time.hour").sum().plot(label="AUS2200 SBI",marker="o")
xr.apply_ufunc(
    count_num_of_objs,
    fuzzy_list[0].filtered_labels.sel(lat=darwin_lat,lon=darwin_lon),
    input_core_dims=[["lat","lon"]],
    dask="parallelized",
    vectorize=True).groupby("time.hour").sum().plot(label="AUS2200 fuzzy",marker="o")
plt.legend()
plt.title("Darwin")
plt.ylabel("Total number of sea breeze objects")

ax=plt.subplot(3,2,4)
xr.apply_ufunc(
    count_num_of_objs,
    F_list[0].filtered_labels.sel(lat=perth_lat,lon=perth_lon),
    input_core_dims=[["lat","lon"]],
    dask="parallelized",
    vectorize=True).groupby("time.hour").sum().plot(label="AUS2200 Fc",marker="o")
xr.apply_ufunc(
    count_num_of_objs,
    sbi_list[0].filtered_labels.sel(lat=perth_lat,lon=perth_lon),
    input_core_dims=[["lat","lon"]],
    dask="parallelized",
    vectorize=True).groupby("time.hour").sum().plot(label="AUS2200 SBI",marker="o")
xr.apply_ufunc(
    count_num_of_objs,
    fuzzy_list[0].filtered_labels.sel(lat=perth_lat,lon=perth_lon),
    input_core_dims=[["lat","lon"]],
    dask="parallelized",
    vectorize=True).groupby("time.hour").sum().plot(label="AUS2200 fuzzy",marker="o")
plt.legend()
plt.title("Perth")
plt.ylabel("Total number of sea breeze objects")

ax=plt.subplot(3,2,6)
xr.apply_ufunc(
    count_num_of_objs,
    F_list[0].filtered_labels.sel(lat=gipps_lat,lon=gipps_lon),
    input_core_dims=[["lat","lon"]],
    dask="parallelized",
    vectorize=True).groupby("time.hour").sum().plot(label="AUS2200 Fc",marker="o")
xr.apply_ufunc(
    count_num_of_objs,
    sbi_list[0].filtered_labels.sel(lat=gipps_lat,lon=gipps_lon),
    input_core_dims=[["lat","lon"]],
    dask="parallelized",
    vectorize=True).groupby("time.hour").sum().plot(label="AUS2200 SBI",marker="o")
xr.apply_ufunc(
    count_num_of_objs,
    fuzzy_list[0].filtered_labels.sel(lat=gipps_lat,lon=gipps_lon),
    input_core_dims=[["lat","lon"]],
    dask="parallelized",
    vectorize=True).groupby("time.hour").sum().plot(label="AUS2200 fuzzy",marker="o")
plt.legend()
plt.title("Gippsland")
plt.ylabel("Total number of sea breeze objects")
# Out:
# Text(0, 0.5, 'Total number of sea breeze objects')

# %%
ax=plt.axes(projection=ccrs.PlateCarree())
Fc_list[0].mask.sel(lat=darwin_lat,lon=darwin_lon).sum("time").plot()
xr.plot.contourf(angle_list[0].sel(lat=darwin_lat,lon=darwin_lon).variance_interp,
                 levels=[0.,0.5],hatches=["","////"],colors="none",add_colorbar=False)
ax.coastlines()

# %%
ax=plt.axes(projection=ccrs.PlateCarree())
#xr.where(
#    (angle_list[0].sel(lat=darwin_lat,lon=darwin_lon).variance<0.5),
#    Fc_list[0].mask.sel(lat=darwin_lat,lon=darwin_lon).sum("time"),
#    np.nan).plot()
angle_list[0].sel(lat=darwin_lat,lon=darwin_lon).angle.plot(cmap="twilight"),
ax.coastlines()

# %%
ax=plt.axes(projection=ccrs.PlateCarree())
Fc_list[0].sel(lat=darwin_lat,lon=darwin_lon,time="2016-01-21 09:00").mask.plot()
ax.coastlines()

# %%
ax=plt.axes(projection=ccrs.PlateCarree())
#(angle_list[0].sel(lat=darwin_lat,lon=darwin_lon).variance_interp>0.2).plot()
(angle_list[0].variance_interp>=0.5).plot()
ax.coastlines()

# %%
ax=plt.axes(projection=ccrs.PlateCarree())
xr.open_dataset(
    "/g/data/ng72/ab4502/sea_breeze_detection/aus2200_smooth_s4/Fc_mjo-elnino2016_201601010000_201601312300.zarr/"
    ,engine="zarr",chunks={"time":50}).sel(lat=darwin_lat,lon=darwin_lon).Fc.mean("time").plot(robust=True)
ax.coastlines()
# Out:
# 2025-04-17 13:34:17,811 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.37 GiB -- Worker memory limit: 9.00 GiB
# 2025-04-17 13:34:17,972 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.33 GiB -- Worker memory limit: 9.00 GiB
# ...

# %%
Fc_list[0].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="AUS2200 Fc",marker="o")
sbi_list[0].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="AUS2200 SBI",marker="o")
fuzzy_list[0].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="AUS2200 fuzzy",marker="o")
plt.legend()
plt.title("Perth method comparison AUS2200")

plt.figure()
Fc_list[0].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="AUS2200 Fc",marker="o")
Fc_list[1].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="BARRA-C Fc",marker="o")
Fc_list[2].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="BARRA-R Fc",marker="o")
Fc_list[3].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="ERA5 Fc",marker="o")
plt.legend()
plt.title("Perth model comparison Fc")

plt.figure()
fuzzy_list[0].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="AUS2200 fuzzy",marker="o")
fuzzy_list[1].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="BARRA-C fuzzy",marker="o")
fuzzy_list[2].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="BARRA-R fuzzy",marker="o")
fuzzy_list[3].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="ERA5 fuzzy",marker="o")
plt.legend()
plt.title("Perth model comparison fuzzy")

plt.figure()
sbi_list[0].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="AUS2200 sbi",marker="o")
sbi_list[1].sel(lat=perth_lat,lon=perth_lon).max(("lat","lon")).groupby("time.hour").sum().plot(label="ERA5 sbi",marker="o")
plt.legend()
plt.title("Perth model comparison sbi")
# Out:
# Text(0.5, 1.0, 'Perth model comparison sbi')

# %%
perth_lat, perth_lon = utils.get_perth_bounds()
large_perth_lat, large_perth_lon = utils.get_perth_large_bounds()

plt.figure(figsize=[18,6])

ax=plt.subplot(1,3,1,projection=ccrs.PlateCarree())
da = Fc_list[0].sel(lat=large_perth_lat, lon=large_perth_lon)
xr.where(da.sum("time") >= 5,
         da.groupby("time.hour").sum().idxmax("hour"),
         np.nan).plot(cmap="twilight_shifted",levels=np.arange(0,27,3))
ax.coastlines(color="k",lw=2)

ax=plt.subplot(1,3,2,projection=ccrs.PlateCarree())
da = sbi_list[0].sel(lat=large_perth_lat, lon=large_perth_lon)
xr.where(da.sum("time") >= 5,
         da.groupby("time.hour").sum().idxmax("hour"),
         np.nan).plot(cmap="twilight_shifted",levels=np.arange(0,27,3))
ax.coastlines(color="k",lw=2)

ax=plt.subplot(1,3,3,projection=ccrs.PlateCarree())
da = fuzzy_list[0].sel(lat=large_perth_lat, lon=large_perth_lon)
xr.where(da.sum("time") >= 5,
         da.groupby("time.hour").sum().idxmax("hour"),
         np.nan).plot(cmap="twilight_shifted",levels=np.arange(0,27,3))
ax.coastlines(color="k",lw=2)

# %%
def calc_hourly_max(da,min_hours):

    hour_counts = da.groupby("time.hour").sum()
    hour_max = hour_counts.argmax("hour")
    hour_max_masked = xr.where(da.sum("time") >= min_hours, hour_max, np.nan)

    return hour_max_masked

min_hours=5
fc_hour_max_masked = calc_hourly_max(Fc_list[0].chunk({"time":-1,"lon":100,"lat":100}),min_hours).persist()
sbi_hour_max_masked = calc_hourly_max(sbi_list[0].chunk({"time":-1,"lon":100,"lat":100}),min_hours).persist()
fuzzy_hour_max_masked = calc_hourly_max(fuzzy_list[0].chunk({"time":-1,"lon":100,"lat":100}),min_hours).persist()

# %%
perth_lat, perth_lon = utils.get_perth_bounds()
large_perth_lat, large_perth_lon = utils.get_perth_large_bounds()


plt.figure(figsize=[12,20])

ax=plt.subplot(3,1,1,projection=ccrs.PlateCarree())
fc_hour_max_masked.plot(cmap="twilight_shifted",levels=np.arange(0,27,3))
ax.coastlines(color="k",lw=2)

ax=plt.subplot(3,1,2,projection=ccrs.PlateCarree())
sbi_hour_max_masked.plot(cmap="twilight_shifted",levels=np.arange(0,27,3))
ax.coastlines(color="k",lw=2)

ax=plt.subplot(3,1,3,projection=ccrs.PlateCarree())
fuzzy_hour_max_masked.plot(cmap="twilight_shifted",levels=np.arange(0,27,3))
ax.coastlines(color="k",lw=2)
