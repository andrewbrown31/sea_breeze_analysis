# %%
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
#lat_slice=slice(-38,-30)
#lon_slice=slice(112,120)
lat_slice=slice(-38,-20)
lon_slice=slice(110,125)
Fc = xr.open_dataset("/g/data/gb02/ab4502/sea_breeze_detection/barra_r/Fc_201601010000_201601312300.nc")
F = xr.open_dataset("/g/data/gb02/ab4502/sea_breeze_detection/barra_r/F_201601010000_201601312300.nc")
F_dqdt = xr.open_dataset("/g/data/gb02/ab4502/sea_breeze_detection/barra_r/F_dqdt_201601010000_201601312300.nc")
F_hourly = xr.open_dataset("/g/data/gb02/ab4502/sea_breeze_detection/barra_r/F_hourly_201601010000_201601312300.nc")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/g/data/gb02/ab4502/sea_breeze_detection/barra_r/Fc_201601010000_201601312300.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'f95b9442-ba00-4803-a30b-707d99aaed2d']
#
# ...

# %%
plt.figure(figsize=[16,6])

t = "2016-01-22 08:00"

ax=plt.subplot(1,3,1,projection=ccrs.PlateCarree())
Fc.Fc.sel(time=t,lat=lat_slice,lon=lon_slice).plot(ax=ax,robust=True,vmin=-4,vmax=4,cmap="RdBu")
ax.coastlines()

ax=plt.subplot(1,3,2,projection=ccrs.PlateCarree())
F.F.sel(time=t,lat=lat_slice,lon=lon_slice).plot(ax=ax,robust=True,vmin=-4,vmax=4,cmap="RdBu")
ax.coastlines()

ax=plt.subplot(1,3,3,projection=ccrs.PlateCarree())
F_dqdt.dqu_dt.sel(time=t,lat=lat_slice,lon=lon_slice).plot(ax=ax,robust=True,vmin=-0.004,vmax=0.004,cmap="RdBu")
ax.coastlines()

# ax=plt.subplot(2,2,4,projection=ccrs.PlateCarree())
# F_hourly.F_hourly.sel(time=t,lat=lat_slice,lon=lon_slice).plot(ax=ax)
# ax.coastlines()

# %%
t1="2016-01-21 12:00"
t2="2016-01-22 12:00"

barrar_dqdt.sel(time=slice(t1,t2)).dqu_dt.hvplot(
    groupby="time",
    clim=(-0.01,0.01),
    widget_type="scrubber",
    widget_location="bottom",
    cmap="RdBu",
    projection=ccrs.PlateCarree(),
    coastline=True)

# %%
sbi = xr.open_dataset("/g/data/gb02/ab4502/sea_breeze_detection/aus2200/sbi_mjo-elnino_201601010100_201601312300.nc")
sbi_static = xr.open_dataset("/g/data/gb02/ab4502/sea_breeze_detection/aus2200_static/sbi_mjo-elnino_201601010100_201601312300.nc")
sbi_pert = xr.open_dataset("/g/data/gb02/ab4502/sea_breeze_detection/aus2200_pert/sbi_mjo-elnino_201601010100_201601312300.nc")

# %%
plt.figure(figsize=[16,6])

t = "2016-01-22 08:00"

ax=plt.subplot(1,3,1,projection=ccrs.PlateCarree())
sbi.sbi.sel(time=t,lat=lat_slice,lon=lon_slice).plot(ax=ax,robust=True,vmin=0,vmax=1,cmap="Blues")
ax.coastlines()

ax=plt.subplot(1,3,2,projection=ccrs.PlateCarree())
sbi_static.sbi.sel(time=t,lat=lat_slice,lon=lon_slice).plot(ax=ax,robust=True,vmin=0,vmax=1,cmap="Blues")
ax.coastlines()

ax=plt.subplot(1,3,3,projection=ccrs.PlateCarree())
sbi_pert.sbi.sel(time=t,lat=lat_slice,lon=lon_slice).plot(ax=ax,robust=True,vmin=0,vmax=1,cmap="Blues")
ax.coastlines()

# %%
t1="2016-01-21 12:00"
t2="2016-01-22 12:00"

aus2200_sbi.sel(time=slice(t1,t2),lat=lat_slice,lon=lon_slice).sbi.hvplot(
    groupby="time",
    clim=(0,1),
    widget_type="scrubber",
    widget_location="bottom",
    projection=ccrs.PlateCarree(),
    coastline=True)

# %%
era5 = xr.open_dataset("/g/data/gb02/ab4502/sea_breeze_detection/era5/sbi_201601010000_201601312300.nc")
era5_static = xr.open_dataset("/g/data/gb02/ab4502/sea_breeze_detection/era5_static/sbi_201601010000_201601312300.nc")
era5_pert = xr.open_dataset("/g/data/gb02/ab4502/sea_breeze_detection/era5_pert/sbi_201601010000_201601312300.nc")

# %%
plt.figure(figsize=[16,6])

t = "2016-01-22 08:00"

ax=plt.subplot(1,3,1,projection=ccrs.PlateCarree())
era5.sbi.sel(time=t,lat=lat_slice,lon=lon_slice).plot(ax=ax,robust=True,vmin=0,vmax=1,cmap="Blues")
ax.coastlines()

ax=plt.subplot(1,3,2,projection=ccrs.PlateCarree())
era5_static.sbi.sel(time=t,lat=lat_slice,lon=lon_slice).plot(ax=ax,robust=True,vmin=0,vmax=1,cmap="Blues")
ax.coastlines()

ax=plt.subplot(1,3,3,projection=ccrs.PlateCarree())
era5_pert.sbi.sel(time=t,lat=lat_slice,lon=lon_slice).plot(ax=ax,robust=True,vmin=0,vmax=1,cmap="Blues")
ax.coastlines()
