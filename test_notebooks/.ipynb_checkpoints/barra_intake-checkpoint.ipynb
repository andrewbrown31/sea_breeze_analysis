# %%
import intake
import numpy as np
from climtas.nci import GadiClient
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import datetime as dt
import metpy

# %%
client = GadiClient()
client
# Out:
# <Client: 'tcp://127.0.0.1:43287' processes=7 threads=7, memory=32.00 GiB>
# 2024-09-06 15:11:39,452 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-ua925-7f2118fff2865ce5e513223158138e87' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14fc992c5360>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=_ElementwiseFunctionArray(_ElementwiseFunctionArray(LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14fc08354e40>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))), func=functools.partial(<function _apply_mask at 0x14fc9bb4f520>, encoded_fill_values={-2147483647}, decoded_fill_value=nan, dtype=<class 'numpy.float64'>), dtype=dtype('float64')), func=functools.partial(<function _scale_offset_decoding at 0x14fc9bb4f6d0>, scale_factor=0.00390625, add_offset=-37.2578125, dtype=dtype('float64')), dtype=dtype('float64')), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14fc992c5360>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=_ElementwiseFunctionArray(_ElementwiseFunctionArray(LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14fbe4323280>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))), func=functools.partial(<function _apply_mask at 0x14fc9bb4f520>, encoded_fill_values={-2147483647}, decoded_fill_value=nan, dtype=<class 'numpy.float64'>), dtype=dtype('float64')), func=functools.partial(<function _scale_offset_decoding at 0x14fc9bb4f6d0>, scale_factor=0.00390625, add_offset=-37.2578125, dtype=dtype('float64')), dtype=dtype('float64')), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('32387e90faaf7ef5', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('9a46859e8fc5e168', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-09-06 15:12:51,599 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-va850-702108ef8f24e6815e6024229d3832fe' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: memory
# old run_spec: (<function execute_task at 0x14fc992c5360>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=_ElementwiseFunctionArray(_ElementwiseFunctionArray(LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14fc1447cdc0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))), func=functools.partial(<function _apply_mask at 0x14fc9bb4f520>, encoded_fill_values={-2147483647}, decoded_fill_value=nan, dtype=<class 'numpy.float64'>), dtype=dtype('float64')), func=functools.partial(<function _scale_offset_decoding at 0x14fc9bb4f6d0>, scale_factor=0.00390625, add_offset=-44.01171875, dtype=dtype('float64')), dtype=dtype('float64')), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14fc992c5360>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=_ElementwiseFunctionArray(_ElementwiseFunctionArray(LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14fbe5edf2c0>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))), func=functools.partial(<function _apply_mask at 0x14fc9bb4f520>, encoded_fill_values={-2147483647}, decoded_fill_value=nan, dtype=<class 'numpy.float64'>), dtype=dtype('float64')), func=functools.partial(<function _scale_offset_decoding at 0x14fc9bb4f6d0>, scale_factor=0.00390625, add_offset=-44.01171875, dtype=dtype('float64')), dtype=dtype('float64')), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('cb7765e115e9ffc4', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('4aeb81a03fb37ef7', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-09-06 15:12:58,116 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-uas-bed55952ae0c3ed4d26a068b2511e986' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14fc992c5360>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=_ElementwiseFunctionArray(_ElementwiseFunctionArray(LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14fc14643e80>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))), func=functools.partial(<function _apply_mask at 0x14fc9bb4f520>, encoded_fill_values={-2147483647}, decoded_fill_value=nan, dtype=<class 'numpy.float64'>), dtype=dtype('float64')), func=functools.partial(<function _scale_offset_decoding at 0x14fc9bb4f6d0>, scale_factor=0.0009765625, add_offset=-35.09375, dtype=dtype('float64')), dtype=dtype('float64')), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14fc992c5360>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=_ElementwiseFunctionArray(_ElementwiseFunctionArray(LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14fbdbdc2a40>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))), func=functools.partial(<function _apply_mask at 0x14fc9bb4f520>, encoded_fill_values={-2147483647}, decoded_fill_value=nan, dtype=<class 'numpy.float64'>), dtype=dtype('float64')), func=functools.partial(<function _scale_offset_decoding at 0x14fc9bb4f6d0>, scale_factor=0.0009765625, add_offset=-35.09375, dtype=dtype('float64')), dtype=dtype('float64')), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('a79f02a8bcb386fb', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('1e89d83fec1113a4', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-09-06 15:13:16,590 - distributed.dashboard.components.scheduler - ERROR - 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# 2024-09-06 15:13:16,591 - tornado.application - ERROR - Uncaught exception GET /individual-groups (::1)
# HTTPServerRequest(protocol='http', host='gadi-cpu-bdw-0041.gadi.nci.org.au:8682', method='GET', uri='/individual-groups', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/web.py", line 1790, in _execute
#     result = await result
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/views/doc_handler.py", line 54, in get
#     session = await self.get_session()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/views/session_handler.py", line 145, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/contexts.py", line 240, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/application/application.py", line 190, in initialize_document
#     h.modify_document(doc)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/application/handlers/function.py", line 140, in modify_document
#     self._func(doc)
#   File "cytoolz/functoolz.pyx", line 263, in cytoolz.functoolz.curry.__call__
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 4795, in individual_doc
#     fig.update()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2690, in update
#     self.nodes_layout, self.arrows_layout = self.update_layout()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# 2024-09-06 15:13:16,759 - distributed.scheduler - ERROR -
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4716, in _create_taskstate_from_graph
#     plugin.update_graph(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/diagnostics/websocket.py", line 38, in update_graph
#     self.socket.send("update_graph", {"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/http/scheduler/info.py", line 275, in send
#     self.write_message(data)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-09-06 15:13:16,822 - distributed.dashboard.components.scheduler - ERROR - 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# 2024-09-06 15:13:17,066 - bokeh.util.tornado - ERROR - Error thrown from periodic callback:
# 2024-09-06 15:13:17,068 - bokeh.util.tornado - ERROR - Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 226, in with_document_locked
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 486, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 444, in invoke_with_curdoc
#     return f()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 485, in invoke
#     return f(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 41, in <lambda>
#     doc.add_periodic_callback(lambda: update(ref), interval)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 49, in update
#     comp.update()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2690, in update
#     self.nodes_layout, self.arrows_layout = self.update_layout()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
#
# 2024-09-06 15:13:17,088 - distributed.dashboard.components.scheduler - ERROR - 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# 2024-09-06 15:13:17,293 - bokeh.util.tornado - ERROR - Error thrown from periodic callback:
# 2024-09-06 15:13:17,295 - bokeh.util.tornado - ERROR - Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 226, in with_document_locked
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 486, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 444, in invoke_with_curdoc
#     return f()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 485, in invoke
#     return f(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 41, in <lambda>
#     doc.add_periodic_callback(lambda: update(ref), interval)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 49, in update
#     comp.update()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2690, in update
#     self.nodes_layout, self.arrows_layout = self.update_layout()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
#
# 2024-09-06 15:13:17,310 - distributed.dashboard.components.scheduler - ERROR - 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# 2024-09-06 15:13:17,507 - bokeh.util.tornado - ERROR - Error thrown from periodic callback:
# 2024-09-06 15:13:17,508 - bokeh.util.tornado - ERROR - Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 226, in with_document_locked
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 486, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 444, in invoke_with_curdoc
#     return f()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 485, in invoke
#     return f(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 41, in <lambda>
#     doc.add_periodic_callback(lambda: update(ref), interval)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 49, in update
#     comp.update()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2690, in update
#     self.nodes_layout, self.arrows_layout = self.update_layout()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
#
# 2024-09-06 15:13:17,521 - distributed.dashboard.components.scheduler - ERROR - 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py:6051: UserWarning: Scheduler already contains a plugin with name websocket; overwriting.
#   warnings.warn(
# 2024-09-06 15:13:17,738 - bokeh.util.tornado - ERROR - Error thrown from periodic callback:
# 2024-09-06 15:13:17,739 - bokeh.util.tornado - ERROR - Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 226, in with_document_locked
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 486, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 444, in invoke_with_curdoc
#     return f()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 485, in invoke
#     return f(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 41, in <lambda>
#     doc.add_periodic_callback(lambda: update(ref), interval)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 49, in update
#     comp.update()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2690, in update
#     self.nodes_layout, self.arrows_layout = self.update_layout()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
#
# 2024-09-06 15:13:17,751 - distributed.dashboard.components.scheduler - ERROR - 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# 2024-09-06 15:13:17,964 - bokeh.util.tornado - ERROR - Error thrown from periodic callback:
# 2024-09-06 15:13:17,965 - bokeh.util.tornado - ERROR - Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 226, in with_document_locked
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 486, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 444, in invoke_with_curdoc
#     return f()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 485, in invoke
#     return f(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 41, in <lambda>
#     doc.add_periodic_callback(lambda: update(ref), interval)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 49, in update
#     comp.update()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2690, in update
#     self.nodes_layout, self.arrows_layout = self.update_layout()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
#
# 2024-09-06 15:13:17,977 - distributed.dashboard.components.scheduler - ERROR - 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# 2024-09-06 15:13:18,178 - bokeh.util.tornado - ERROR - Error thrown from periodic callback:
# 2024-09-06 15:13:18,179 - bokeh.util.tornado - ERROR - Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 226, in with_document_locked
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 486, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 444, in invoke_with_curdoc
#     return f()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 485, in invoke
#     return f(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 41, in <lambda>
#     doc.add_periodic_callback(lambda: update(ref), interval)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 49, in update
#     comp.update()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2690, in update
#     self.nodes_layout, self.arrows_layout = self.update_layout()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
#
# 2024-09-06 15:13:18,189 - distributed.dashboard.components.scheduler - ERROR - 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# 2024-09-06 15:13:18,412 - bokeh.util.tornado - ERROR - Error thrown from periodic callback:
# 2024-09-06 15:13:18,414 - bokeh.util.tornado - ERROR - Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 226, in with_document_locked
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 486, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 444, in invoke_with_curdoc
#     return f()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 485, in invoke
#     return f(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 41, in <lambda>
#     doc.add_periodic_callback(lambda: update(ref), interval)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 49, in update
#     comp.update()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2690, in update
#     self.nodes_layout, self.arrows_layout = self.update_layout()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
#
# 2024-09-06 15:13:18,423 - distributed.dashboard.components.scheduler - ERROR - 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# 2024-09-06 15:13:18,644 - bokeh.util.tornado - ERROR - Error thrown from periodic callback:
# 2024-09-06 15:13:18,645 - bokeh.util.tornado - ERROR - Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 226, in with_document_locked
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 486, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 444, in invoke_with_curdoc
#     return f()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 485, in invoke
#     return f(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 41, in <lambda>
#     doc.add_periodic_callback(lambda: update(ref), interval)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 49, in update
#     comp.update()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2690, in update
#     self.nodes_layout, self.arrows_layout = self.update_layout()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
#
# 2024-09-06 15:13:18,653 - distributed.dashboard.components.scheduler - ERROR - 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in <genexpr>
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# KeyError: 'rechunk-split-59ba3754dd547404bd0f69eeab3e3cde'
# 2024-09-06 15:13:18,871 - bokeh.util.tornado - ERROR - Error thrown from periodic callback:
# 2024-09-06 15:13:18,872 - bokeh.util.tornado - ERROR - Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/gen.py", line 530, in callback
#     result_list.append(f.result())
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/server/session.py", line 226, in with_document_locked
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 486, in wrapper
#     return invoke_with_curdoc(doc, invoke)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 444, in invoke_with_curdoc
#     return f()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/document/callbacks.py", line 485, in invoke
#     return f(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 41, in <lambda>
#     doc.add_periodic_callback(lambda: update(ref), interval)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/__init__.py", line 49, in update
#     comp.update()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2690, in update
#     self.nodes_layout, self.arrows_layout = self.update_layout()
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 843, in wrapper
#     return func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/dashboard/components/scheduler.py", line 2641, in update_layout
#     x = max(xs[dep] for dep in dependencies[tg]) + 1
# ...
#     plugin.update_graph(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/diagnostics/websocket.py", line 38, in update_graph
#     self.socket.send("update_graph", {"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/http/scheduler/info.py", line 275, in send
#     self.write_message(data)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-09-06 15:46:46,907 - distributed.scheduler - ERROR -
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4716, in _create_taskstate_from_graph
#     plugin.update_graph(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/diagnostics/websocket.py", line 38, in update_graph
#     self.socket.send("update_graph", {"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/http/scheduler/info.py", line 275, in send
#     self.write_message(data)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-09-06 15:46:47,449 - distributed.scheduler - ERROR -
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4716, in _create_taskstate_from_graph
#     plugin.update_graph(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/diagnostics/websocket.py", line 38, in update_graph
#     self.socket.send("update_graph", {"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/http/scheduler/info.py", line 275, in send
#     self.write_message(data)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-09-06 15:46:47,777 - distributed.scheduler - ERROR -
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4716, in _create_taskstate_from_graph
#     plugin.update_graph(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/diagnostics/websocket.py", line 38, in update_graph
#     self.socket.send("update_graph", {"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/http/scheduler/info.py", line 275, in send
#     self.write_message(data)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-09-06 15:47:08,417 - distributed.scheduler - WARNING - Detected different `run_spec` for key 'original-open_dataset-ua150m-efa15d1ada796e9e0a3c1a80833f935e' between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: (<function execute_task at 0x14fc992c5360>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=_ElementwiseFunctionArray(_ElementwiseFunctionArray(LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14fbd2e99300>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))), func=functools.partial(<function _apply_mask at 0x14fc9bb4f520>, encoded_fill_values={-2147483647}, decoded_fill_value=nan, dtype=<class 'numpy.float64'>), dtype=dtype('float64')), func=functools.partial(<function _scale_offset_decoding at 0x14fc9bb4f6d0>, scale_factor=0.000244140625, add_offset=-47.8330078125, dtype=dtype('float64')), dtype=dtype('float64')), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# new run_spec: (<function execute_task at 0x14fc992c5360>, (ImplicitToExplicitIndexingAdapter(array=CopyOnWriteArray(array=LazilyIndexedArray(array=_ElementwiseFunctionArray(_ElementwiseFunctionArray(LazilyIndexedArray(array=<xarray.backends.netCDF4_.NetCDF4ArrayWrapper object at 0x14fbcb118500>, key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))), func=functools.partial(<function _apply_mask at 0x14fc9bb4f520>, encoded_fill_values={-2147483647}, decoded_fill_value=nan, dtype=<class 'numpy.float64'>), dtype=dtype('float64')), func=functools.partial(<function _scale_offset_decoding at 0x14fc9bb4f6d0>, scale_factor=0.000244140625, add_offset=-47.8330078125, dtype=dtype('float64')), dtype=dtype('float64')), key=BasicIndexer((slice(None, None, None), slice(None, None, None), slice(None, None, None)))))),), {})
# old token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('aaf67f44c645798c', [])]), ('dict', [])])
# new token: ('tuple', [('80935a1067ef908b', []), ('tuple', [('7dccf70f49192aea', [])]), ('dict', [])])
# old dependencies: set()
# new dependencies: set()
#
# 2024-09-06 15:47:42,433 - distributed.scheduler - ERROR -
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4716, in _create_taskstate_from_graph
#     plugin.update_graph(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/diagnostics/websocket.py", line 38, in update_graph
#     self.socket.send("update_graph", {"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/http/scheduler/info.py", line 275, in send
#     self.write_message(data)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-09-06 15:47:45,974 - distributed.scheduler - ERROR -
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 5829, in remove_client
#     plugin.remove_client(scheduler=self, client=client)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/diagnostics/websocket.py", line 34, in remove_client
#     self.socket.send("remove_client", {"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/http/scheduler/info.py", line 275, in send
#     self.write_message(data)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-09-06 15:47:46,396 - distributed.scheduler - ERROR -
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 5774, in add_client
#     plugin.add_client(scheduler=self, client=client)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/diagnostics/websocket.py", line 30, in add_client
#     self.socket.send("add_client", {"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/http/scheduler/info.py", line 275, in send
#     self.write_message(data)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-09-06 15:51:05,935 - distributed.scheduler - ERROR - ('mean_agg-aggregate-932fb14e4813bd3e9bc834a7d0ee1b42', 0, 0)
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 837, in wrapper
#     return await func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4788, in update_graph
#     self._create_taskstate_from_graph(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4602, in _create_taskstate_from_graph
#     lost_keys = self._match_graph_with_tasks(dsk, dependencies, keys)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4534, in _match_graph_with_tasks
#     del dsk[k]
# KeyError: ('mean_agg-aggregate-932fb14e4813bd3e9bc834a7d0ee1b42', 0, 0)
# 2024-09-06 15:51:05,937 - distributed.scheduler - ERROR -
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 5792, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/core.py", line 910, in handle_stream
#     await handler(**merge(extra, msg))
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 837, in wrapper
#     return await func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4788, in update_graph
#     self._create_taskstate_from_graph(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4602, in _create_taskstate_from_graph
#     lost_keys = self._match_graph_with_tasks(dsk, dependencies, keys)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4534, in _match_graph_with_tasks
#     del dsk[k]
# KeyError: ('mean_agg-aggregate-932fb14e4813bd3e9bc834a7d0ee1b42', 0, 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 5829, in remove_client
#     plugin.remove_client(scheduler=self, client=client)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/diagnostics/websocket.py", line 34, in remove_client
#     self.socket.send("remove_client", {"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/http/scheduler/info.py", line 275, in send
#     self.write_message(data)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-09-06 15:51:05,940 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/core.py", line 829, in _handle_comm
#     result = await result
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 5792, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/core.py", line 910, in handle_stream
#     await handler(**merge(extra, msg))
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 837, in wrapper
#     return await func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4788, in update_graph
#     self._create_taskstate_from_graph(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4602, in _create_taskstate_from_graph
#     lost_keys = self._match_graph_with_tasks(dsk, dependencies, keys)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4534, in _match_graph_with_tasks
#     del dsk[k]
# KeyError: ('mean_agg-aggregate-932fb14e4813bd3e9bc834a7d0ee1b42', 0, 0)
# Task exception was never retrieved
# future: <Task finished name='Task-1246480' coro=<Server._handle_comm() done, defined at /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/core.py:735> exception=KeyError(('mean_agg-aggregate-932fb14e4813bd3e9bc834a7d0ee1b42', 0, 0))>
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/core.py", line 829, in _handle_comm
#     result = await result
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 5792, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/core.py", line 910, in handle_stream
#     await handler(**merge(extra, msg))
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/utils.py", line 837, in wrapper
#     return await func(*args, **kwargs)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4788, in update_graph
#     self._create_taskstate_from_graph(
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4602, in _create_taskstate_from_graph
#     lost_keys = self._match_graph_with_tasks(dsk, dependencies, keys)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 4534, in _match_graph_with_tasks
#     del dsk[k]
# KeyError: ('mean_agg-aggregate-932fb14e4813bd3e9bc834a7d0ee1b42', 0, 0)
# 2024-09-06 15:51:05,948 - distributed.scheduler - ERROR -
# Traceback (most recent call last):
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/scheduler.py", line 5774, in add_client
#     plugin.add_client(scheduler=self, client=client)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/diagnostics/websocket.py", line 30, in add_client
#     self.socket.send("add_client", {"client": client})
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/http/scheduler/info.py", line 275, in send
#     self.write_message(data)
#   File "/g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/tornado/websocket.py", line 332, in write_message
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError

# %%
#See here: https://opus.nci.org.au/pages/viewpage.action?pageId=264241965
data_catalog = intake.open_esm_datastore("/g/data/ob53/catalog/v2/esm/catalog.json")

# %%
#ds = data_catalog.search(variable_id="uas",domain_id="AUS-11",freq="1hr",start_time=[202312,202401,202402]).to_dask(xarray_open_kwargs={'chunks':{'time':-1}})

def combine_winds(u,v,uname,vname,ws_name):

    wind_da = xr.Dataset({uname:u[uname],vname:v[vname]})
    wind_da[ws_name] = np.sqrt(wind_da[uname]**2 + wind_da[vname]**2)

    return wind_da

lat_slice = slice(-44,-29)
lon_slice = slice(140,156)

unames = ["uas","ua50m","ua100m","ua150m","ua200m","ua250m","ua1500m"]
vnames = ["vas","va50m","va100m","va150m","va200m","va250m","va1500m"]
ws_names = ["ws_sfc","ws_50m","ws_100m","ws_150m","ws_200m","ws_250m","ws_1500m"]

# unames = ["uas","ua1000","ua925","ua850","ua700"]
# vnames = ["vas","va1000","va925","va850","va700"]
# ws_names = ["ws_sfc","ws_1000","ws_925","ws_850","ws_va700"]

times = [202312,202401,202402]

wind_ds_list = []
for uname,vname,wsname in zip(unames,vnames,ws_names):
    u_ds = data_catalog.search(variable_id=uname,
                        domain_id="AUS-11",
                        freq="1hr",
                        start_time=times).to_dask().sel(lon=lon_slice, lat=lat_slice)
    v_ds = data_catalog.search(variable_id=vname,
                        domain_id="AUS-11",
                        freq="1hr",
                        start_time=times).to_dask().sel(lon=lon_slice, lat=lat_slice)
    wind_ds_list.append(combine_winds(u_ds,v_ds,uname,vname,wsname)\
                       .chunk({"time":-1,"lat":20,"lon":20}))

# %%
wind_ds = xr.merge(wind_ds_list,compat="override")

# %%
wind_mean = wind_ds.mean("time").persist()
wind_grouped = wind_ds.groupby("time.hour").mean()
wind_hourly_anom = (wind_grouped - wind_mean).persist()

# %%
def plot_wind(wind_ds,uname,vname,wsname,ax,vmax=None,vmin=None,cmap=None,ws=True):
    if ws:
        wind_ds[wsname].plot(vmax=vmax,vmin=vmin,cmap=cmap)
    wind_ds[[uname,vname]].coarsen({"lon":5,"lat":5},boundary="pad").mean().plot.quiver(x="lon",y="lat",u=uname,v=vname,scale=50)
    ax.coastlines()
    ax.gridlines(draw_labels=True)

# %%
plot_wind(wind_mean,"ua100m","va100m","ws_100m",plt.axes(projection=ccrs.PlateCarree()))
# Out:
# ---------------------------------------------------------------------------
# FutureCancelledError                      Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 plot_wind(wind_mean,"ua100m","va100m","ws_100m",plt.axes(projection=ccrs.PlateCarree()))
#
# Cell In[61], line 3, in plot_wind(wind_ds, uname, vname, wsname, ax, vmax, vmin, cmap, ws)
#       1 def plot_wind(wind_ds,uname,vname,wsname,ax,vmax=None,vmin=None,cmap=None,ws=True):
#       2     if ws:
# ----> 3         wind_ds[wsname].plot(vmax=vmax,vmin=vmin,cmap=cmap)
#       4     wind_ds[[uname,vname]].coarsen({"lon":5,"lat":5},boundary="pad").mean().plot.quiver(x="lon",y="lat",u=uname,v=vname,scale=50)
#       5     ax.coastlines()
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:270, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     219 def plot(
#     220     darray: DataArray,
#     221     *,
#    (...)
#     228     **kwargs: Any,
#     229 ) -> Any:
#     230     """
#     231     Default plot of DataArray using :py:mod:`matplotlib:matplotlib.pyplot`.
#     232
#    (...)
#     266     xarray.DataArray.squeeze
#     267     """
#     268     darray = darray.squeeze(
#     269         d for d, s in darray.sizes.items() if s == 1 and d not in (row, col, hue)
# --> 270     ).compute()
#     272     plot_dims = set(darray.dims)
#     273     plot_dims.discard(row)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/core/dataarray.py:1179, in DataArray.compute(self, **kwargs)
#    1154 """Manually trigger loading of this array's data from disk or a
#    1155 remote source into memory and return a new array.
#    1156
#    (...)
#    1176 dask.compute
#    1177 """
#    1178 new = self.copy(deep=False)
# -> 1179 return new.load(**kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/core/dataarray.py:1147, in DataArray.load(self, **kwargs)
#    1127 def load(self, **kwargs) -> Self:
#    1128     """Manually trigger loading of this array's data from disk or a
#    1129     remote source into memory and return this array.
#    1130
#    (...)
#    1145     dask.compute
#    1146     """
# -> 1147     ds = self._to_temp_dataset().load(**kwargs)
#    1148     new = self._from_temp_dataset(ds)
#    1149     self._variable = new._variable
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/core/dataset.py:863, in Dataset.load(self, **kwargs)
#     860 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     862 # evaluate all the chunked arrays simultaneously
# --> 863 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     864     *lazy_data.values(), **kwargs
#     865 )
#     867 for k, data in zip(lazy_data, evaluated_data):
#     868     self.variables[k].data = data
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/namedarray/daskmanager.py:86, in DaskManager.compute(self, *data, **kwargs)
#      81 def compute(
#      82     self, *data: Any, **kwargs: Any
#      83 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      84     from dask.array import compute
# ---> 86     return compute(*data, **kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:2423, in Client._gather(self, futures, errors, direct, local_worker)
#    2421     exception = st.exception
#    2422     traceback = st.traceback
# -> 2423     raise exception.with_traceback(traceback)
#    2424 if errors == "skip":
#    2425     bad_keys.add(key)
#
# FutureCancelledError: ('mean_agg-aggregate-932fb14e4813bd3e9bc834a7d0ee1b42', 6, 5) cancelled for reason: scheduler-connection-lost.
# Client lost the connection to the scheduler. Please check your connection and re-run your work.

# %%
cnt=1
plt.figure(figsize=[12,18])
for hour in [0,3,6,9,12,15,18,21]:
    ax=plt.subplot(4,2,cnt,projection=ccrs.PlateCarree())
    plot_wind(wind_hourly_anom.sel(hour=hour),"ua100m","va100m","ws_100m",ax=ax,vmin=-2,vmax=2, cmap="RdBu_r")
    plt.title(str(hour) +" UTC")
    cnt=cnt+1

# %%
unames = ["uas","ua100m","ua200m","ua1500m"]
vnames = ["vas","va100m","va200m","va1500m"]

plt.figure(figsize=[14,6])
plt.subplot(1,2,1)
lat = -38
lon=148
for uname,vname in zip(unames,vnames):
    wind_hourly_anom_point = wind_hourly_anom.sel(lat=lat,lon=lon,method="nearest")
    
    u_comp = wind_hourly_anom_point[uname].values
    v_comp = wind_hourly_anom_point[vname].values
    u_comp = np.append(u_comp,u_comp[0])
    v_comp = np.append(v_comp,v_comp[0])
    
    plt.plot(u_comp,v_comp,marker="o",label=uname)
    [plt.text(u_comp[i],v_comp[i],str(i),ha="center",va="bottom",size=10) for i in [0,6,12,18]]
    plt.gca().grid(ls=":")
    plt.plot([0,0],[-2.5,2.5],color="k",ls="--")
    plt.plot([-2.5,2.5],[0,0],color="k",ls="--")
plt.legend()
plt.title("Gippsland hodograph (anomaly)")
