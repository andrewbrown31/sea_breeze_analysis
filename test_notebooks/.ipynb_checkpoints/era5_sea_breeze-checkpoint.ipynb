# %%
from climtas.nci import GadiClient
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import metpy
import wrf
import numpy as np

# %%
client = GadiClient()
client
# Out:
# <Client: 'tcp://127.0.0.1:42379' processes=7 threads=7, memory=32.00 GiB>

# %%
#Data here downloaded using era5_download_google.ipynb
f = xr.open_dataset("/g/data/gb02/ab4502/era5_test.nc",chunks={"latitude":5,"longitude":5})

#Adjust geopotential to height above surface
g = 9.80665    #https://confluence.ecmwf.int/display/CKB/ERA5%3A+compute+pressure+and+geopotential+on+model+levels%2C+geopotential+height+and+geometric+height#heading-Geopotentialheight
topo = xr.open_dataset("/g/data/gb02/ab4502/era5_static/raw_date-variable-static_2021_12_31_geopotential_static.nc")
topo = topo.squeeze().sel(longitude=f.longitude, latitude=f.latitude)["z"] / g
f["geopotential"] = (f["geopotential"] / g) - topo
f = f.rename({"geopotential":"geopotential_hgt_agl"})

# %%
ax=plt.axes(projection=ccrs.PlateCarree())
f.u_component_of_wind.isel(hybrid=-1).mean("time").plot()
ax.coastlines()
ax.gridlines(draw_labels=["left","bottom"])

start_points = [151.5,-31.5]
end_points = [154,-31.5]
plt.plot([start_points[0],end_points[0]], [start_points[1],end_points[1]], color="k")

# %%
temp = f.isel(time=[0,50])
#temp["geopotential_hgt_agl"] = temp["geopotential_hgt_agl"] * metpy.units.units.meter
#temp = temp.metpy.parse_cf()
#temp = temp.rename({"hybrid":"vertical"})
temp = temp.isel(hybrid=slice(None,None,-1))

# %%
def interp_np(x, xp, fp):
    return np.interp(x, xp, fp)


# xr.apply_ufunc(interp_np,
#                50,
#                temp["geopotential_hgt_agl"],
#                temp["u_component_of_wind"],
#                input_core_dims=[ [], ["hybrid"], ["hybrid"]],
#                dask="parallelized",
#                output_dtypes=float,
#                vectorize=True).isel(time=1).plot()


interp_temp = xr.apply_ufunc(interp_np,
               np.array([50,500]),
               temp["geopotential_hgt_agl"],
               temp["u_component_of_wind"],
               input_core_dims=[ ["height"], ["hybrid"], ["hybrid"]],
               output_core_dims=[["height"]],
               exclude_dims=set(("hybrid",)),
               dask="parallelized",
               output_dtypes=temp["u_component_of_wind"].dtype,
               vectorize=True)#.plot()

# %%
interp_temp
# Out:
# <xarray.DataArray (time: 2, latitude: 45, longitude: 65, height: 2)> Size: 47kB
# dask.array<transpose, shape=(2, 45, 65, 2), dtype=float32, chunksize=(2, 5, 5, 2), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float32 180B -29.0 -29.25 -29.5 ... -39.5 -39.75 -40.0
#   * longitude  (longitude) float32 260B 140.0 140.2 140.5 ... 155.5 155.8 156.0
#   * time       (time) datetime64[ns] 16B 2024-01-01 2024-01-03T02:00:00
# Dimensions without coordinates: height

# %%
temp["u_component_of_wind"].isel(time=1,hybrid=13).plot()

# %%
temp["geopotential_hgt_agl"].mean(("latitude","longitude","time")).values
# Out:
# array([  10.52577127,   32.34366137,   56.20479866,   82.29024683,
#         110.80075908,  141.95292184,  175.97908591,  213.12847512,
#         253.66637859,  297.87630938,  346.05827963,  398.53222761,
#         455.63663013,  517.72987246,  585.18898993,  658.4099647 ,
#         737.80772707,  823.80857498,  916.84574211, 1017.3615283 ,
#        1125.8045986 , 1242.62153173, 1368.2381239 , 1503.05783738,
#        1647.47327974, 1801.85936487, 1966.55480564, 2141.83053791,
#        2327.87462403, 2524.78741396, 2732.58151222, 2951.17442363,
#        3180.39292607, 3419.98599377, 3669.60193636, 3928.78051325,
#        4196.9197507 , 4473.24282244])

# %%
# start_point = wrf.CoordPair(lat=start_points[1],lon=start_points[0])
# end_point = wrf.CoordPair(lat=end_points[1],lon=end_points[0])    
# wrf.vertcross(temp.u_component_of_wind, 
#               temp.geopotential_hgt_agl, 
#               levels=np.linspace(0,3000,20),
#               start_point=start_point,
#               end_point=end_point,
#              latlon=True)

# %%
temp["u_component_of_wind"].dtype
# Out:
# dtype('float32')
